# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.chrome.options import Options as ChromeOptions
from selenium.webdriver.support import expected_conditions as EC
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver import ActionChains
from pythainlp.util import isthai
from bs4 import BeautifulSoup
import pandas as pd
import time
import os
import re
import random
import undetected_chromedriver as uc

# %%
prefs = {"profile.default_content_setting_values.notifications": 1}
options = webdriver.ChromeOptions()
options.add_experimental_option("prefs", prefs)
options.add_argument("--disable-blink-features=AutomationControlled")

# %%
def handle_error(driver):
    try:
        # Switch to the iframe where error handling is expected
        iframe = WebDriverWait(driver, 10).until(
            EC.frame_to_be_available_and_switch_to_it((By.ID, "baxia-dialog-content"))
        )
        print("Switched to iframe.")

        # Try locating the refresh button by XPath
        try:
            refresh_button = driver.find_element(By.XPATH, "/html/body/div/div[2]/div/div[1]/div[2]/center/div[1]/div/div/div")
            print("Found the refresh button for nc_1_refresh1.")
        except Exception as e:
            print(f"Could not find the refresh button for nc_1_refresh1: {e}")
            try:
                refresh_button = driver.find_element(By.XPATH, "/html/body/div/div[2]/div/div[1]/div[2]/center/div[1]/div/div/div/i")
                print("Found the refresh button for nc_1_refresh2.")
            except Exception as e:
                print(f"Could not find the refresh button for nc_1_refresh2: {e}")
                return False  # If neither is found, return False

        # Click the refresh button
        refresh_button.click()
        print("Clicked the refresh button.")

        # Wait for the page to refresh
        time.sleep(5)  # Adjust time as needed
        driver.switch_to.default_content()

        # Handling other issues if no error was detected or handled
        try:
            # Switch to the iframe again (make sure it's still valid)
            iframe = WebDriverWait(driver, 10).until(
                EC.frame_to_be_available_and_switch_to_it((By.ID, "baxia-dialog-content"))
            )
            print("Switched to iframe again for slider handling.")

            try:
                # Wait for the slider to appear
                slider = WebDriverWait(driver, 10).until(
                    EC.visibility_of_element_located((By.CSS_SELECTOR, "span#nc_1_n1z.btn_slide"))
                )

                # Parameters for movement with wider random ranges
                step_size = random.choice([5, 10, 15, 20, 25])  # Random step size from a broader range
                initial_pause_time = random.uniform(0.01, 0.5)  # Random initial pause time between 0.01 and 0.5 seconds
                acceleration = random.uniform(1.2, 5)  # Random acceleration factor between 1.2 and 5

                print(f"Step size: {step_size}, Initial pause time: {initial_pause_time}, Acceleration: {acceleration}")

                # Create ActionChains to interact with the slider
                action = ActionChains(driver)
                action.click_and_hold(slider).perform()

                # Use JavaScript to get the width of the slider and its container
                slider_width = driver.execute_script("return document.querySelector('span#nc_1_n1z.btn_slide').offsetWidth;")
                container_width = driver.execute_script("return document.querySelector('span#nc_1_n1z.btn_slide').parentElement.offsetWidth;")
                total_distance = container_width - slider_width

                current_position = driver.execute_script("return arguments[0].getBoundingClientRect().left;", slider)
                current_position -= driver.execute_script("return arguments[0].parentElement.getBoundingClientRect().left;", slider)

                if current_position < total_distance:
                    pause_time = initial_pause_time

                    while current_position < total_distance:
                        move = min(step_size, total_distance - current_position)
                        action.move_by_offset(move, 0).perform()
                        time.sleep(pause_time)
                        current_position += move
                        pause_time = max(pause_time / acceleration, 0.001)  # Ensuring pause time does not go below 0.001 seconds

                    action.release().perform()
                    print("Slider has been moved smoothly.")
                    driver.switch_to.default_content()
                    
                    # Optionally re-check for errors after moving the slider
                    if handle_error(driver):
                        return True  # Exit if error was successfully handled
                else:
                    print("Slider is already in the correct position.")

                time.sleep(5)

            except Exception as e:
                print(f"An error occurred while handling the slider: {e}")

            # Switch back to the main content
            driver.switch_to.default_content()

        except Exception as e:
            print(f"An error occurred while handling the iframe or slider: {e}")
            return False  # Indicate that the error handling failed

    except Exception as e:
        print(f"Error handling failed: {e}")
        driver.switch_to.default_content()
        return False  # Indicate that the error handling failed

    return False

# %%
def is_new_comment(comment_data, content):
    return not any(existing['Message'] == content for existing in comment_data)

# %%
def is_valid_comment(comment):
    thai_pattern = re.compile(r'[\u0E00-\u0E7F\s\d\W]+')
    return thai_pattern.fullmatch(comment)

# %%
#เก็บเว็บเดียว

# %%
def scrape_comments(url, num_comments, star_rating=None):
    driver = webdriver.Chrome(options=options)
    #driver.get("https://www.lazada.co.th/")
    #time.sleep(3)
    driver.get(url)
    time.sleep(3)

    move_slider(driver)

    # Check if the button exists
    button_exit = driver.find_elements(By.CLASS_NAME, "sfo__close")
    if button_exit:
        n = button_exit[0]
        n.click()

    time.sleep(3)
    SCROLL_PAUSE_TIME = 3
    scroll_increment = 400
    while True:
        # Scroll down by the specified increment
        driver.execute_script(f"window.scrollBy(0, {scroll_increment});")
        time.sleep(SCROLL_PAUSE_TIME)
    
        # Check if the filter option is now visible
        try:
            filter_container = WebDriverWait(driver, 1).until(
                EC.visibility_of_element_located((By.CLASS_NAME, "oper"))
            )
            filter_option = filter_container.find_element(By.XPATH, ".//span[@class='condition']")
            if filter_option.is_displayed():
                filter_option.click()  # Click the filter option
                break  # Exit the loop since the filter option is found and clicked
        except Exception as e:
            print(f"Filter not found yet, continue scrolling...")
    
        # Update the current scroll position and total height
        current_scroll_position = driver.execute_script("return window.scrollY;")
        total_height = driver.execute_script("return document.body.scrollHeight;")
    
        # Stop scrolling if the bottom of the page is reached
        if current_scroll_position + scroll_increment >= total_height:
            print("Reached the bottom of the page. Stopping scrolling.")
            break

    time.sleep(3)

    if star_rating is not None:
        try:
            # Wait for the star filter options to appear and click the desired star rating
            star_filter_options = WebDriverWait(driver, 10).until(
                EC.presence_of_element_located((By.CLASS_NAME, "next-menu-content"))
            )
            star_options = star_filter_options.find_elements(By.CLASS_NAME, "next-menu-item")
            star_options[6 - star_rating].click()
            time.sleep(5)
            
            # Switch to the iframe
            try:
                iframe = WebDriverWait(driver, 10).until(
                    EC.frame_to_be_available_and_switch_to_it((By.ID, "baxia-dialog-content"))
                )
                print("Switched to iframe.")
        
                try:
                    # Wait for the slider to appear
                    slider = WebDriverWait(driver, 10).until(
                        EC.visibility_of_element_located((By.CSS_SELECTOR, "span#nc_1_n1z.btn_slide"))
                    )
                
                    # Create ActionChains to interact with the slider
                    action = ActionChains(driver)
                    action.click_and_hold(slider).perform()
                    
                    # Use JavaScript to get the width of the slider and its container
                    slider_width = driver.execute_script("return document.querySelector('span#nc_1_n1z.btn_slide').offsetWidth;")
                    container_width = driver.execute_script("return document.querySelector('span#nc_1_n1z.btn_slide').parentElement.offsetWidth;")
                    total_distance = container_width - slider_width
                    
                    step_size = random.uniform(3, 7)  # Random step size between 3 and 7 pixels
                    initial_pause_time = random.uniform(0.01, 0.05)  # Random initial pause time between 0.01 and 0.05 seconds
                    acceleration = random.uniform(5)  # Random acceleration factor between 1.5 and 3

                    # Get current position of the slider
                    current_position = driver.execute_script("return arguments[0].getBoundingClientRect().left;", slider)
                    
                    # Convert to pixels
                    current_position -= driver.execute_script("return arguments[0].parentElement.getBoundingClientRect().left;", slider)
                    
                    if current_position < total_distance:
                        pause_time = initial_pause_time
                        
                        # Move the slider incrementally, increasing speed
                        while current_position < total_distance:
                            move = min(step_size, total_distance - current_position)
                            action.move_by_offset(move, 0).perform()
                            time.sleep(pause_time)
                            current_position += move
                            pause_time = max(pause_time / acceleration, 0.01)  # Ensure minimum pause time
                        
                        # Release the slider
                        action.release().perform()
                        print("Slider has been moved smoothly.")
                        handle_error(driver)
                    else:
                        print("Slider is already in the correct position.")
                    time.sleep(5)
                
                except Exception as e:
                    print(f"An error occurred while handling the slider: {e}")
        
                # Switch back to the main content
                driver.switch_to.default_content()
            
            except Exception as e:
                print(f"An error occurred while handling the iframe: {e}")
        
        except Exception as e:
            print(f"An error occurred while managing star ratings or iframe: {e}")

    
    time.sleep(5)
    # Get the updated page source
    page_source = driver.page_source

    # Parse the updated HTML content with BeautifulSoup
    soup = BeautifulSoup(page_source, 'html.parser')
  
    comments = soup.find_all('div', class_='item')
    comment_data = []
    while len(comment_data) < num_comments:
        for i, comment in enumerate(comments):
            if len(comment_data) >= num_comments:
                break
            user_element = comment.find('div', class_='middle').find('span')
            message_element = comment.find('div', class_='content')
    
            user = user_element.text.strip() if user_element else ""
            content = message_element.text.strip() if message_element else ""
    
            sentiment = "Positive" if star_rating in [4, 5] else "Neutral" if star_rating == 3 else "Negative" if star_rating in [0, 1, 2] else "-"
    
            if user and content and is_valid_comment(content):
                comment_data.append({'User': user, 'Message': content, 'Sentiment': sentiment})
                print(f"Comment {len(comment_data)}: {user} - {content} - {sentiment}")
    
        if len(comment_data) >= num_comments:
            break
    
        SCROLL_PAUSE_TIME = 3
        scroll_increment = 200
        driver.execute_script(f"window.scrollBy(0, {scroll_increment});")
        time.sleep(SCROLL_PAUSE_TIME)
    
        try:
            next_button = WebDriverWait(driver, 10).until(
                EC.presence_of_element_located((By.CLASS_NAME, 'next'))
            )
            if next_button.is_enabled():
                next_button.click()
                time.sleep(5)  # Wait for new content to load
                
                try:
                    iframe = WebDriverWait(driver, 10).until(
                        EC.frame_to_be_available_and_switch_to_it((By.ID, "baxia-dialog-content"))
                    )
                    print("Switched to iframe.")
                    
                    try:
                        slider = WebDriverWait(driver, 10).until(
                            EC.visibility_of_element_located((By.CSS_SELECTOR, "span#nc_1_n1z.btn_slide"))
                        )
                        
                        action = ActionChains(driver)
                        action.click_and_hold(slider).perform()
                        
                        slider_width = driver.execute_script("return document.querySelector('span#nc_1_n1z.btn_slide').offsetWidth;")
                        container_width = driver.execute_script("return document.querySelector('span#nc_1_n1z.btn_slide').parentElement.offsetWidth;")
                        total_distance = container_width - slider_width
                        
                        step_size = random.uniform(3, 7)  # Random step size between 3 and 7 pixels
                        initial_pause_time = random.uniform(0.01, 0.05)  # Random initial pause time between 0.01 and 0.05 seconds
                        acceleration = random.uniform(1.5, 3)  # Random acceleration factor between 1.5 and 3
                        
                        current_position = 0
                        pause_time = initial_pause_time
                        
                        while current_position < total_distance:
                            move = min(step_size, total_distance - current_position)
                            action.move_by_offset(move, 0).perform()
                            time.sleep(pause_time)
                            current_position += move
                            pause_time = max(pause_time / acceleration, 0.01)
                        action.release().perform()
                        print("Slider has been moved smoothly.")
                        handle_error(driver)
                    except Exception as e:
                        print(f"An error occurred while handling the slider: {e}")
                    
                    driver.switch_to.default_content()
                    
                    page_source = driver.page_source
                    soup = BeautifulSoup(page_source, 'html.parser')
                    comments = soup.find_all('div', class_='item')
                    
                except Exception as e:
                    print(f"An error occurred while handling the iframe: {e}")
            
            else:
                print("Next button is not enabled or not found. Exiting loop.")
                break
        
        except Exception as e:
            print(f"An error occurred while managing the 'next' button or overall process: {e}")
            break
    
    print(f'All Comments: {len(comment_data)}')
    
    df = pd.DataFrame(comment_data)
    # Save the DataFrame to Excel file

    df
    # Check if there are comments to be saved to Excel
#    if not df.empty:
#        # Get the path to the Downloads folder
#        downloads_path = os.path.join(os.path.expanduser("~"), "Downloads")

#        # Save DataFrame to Excel file in the Downloads folder
#        excel_file_path = os.path.join(downloads_path, "comments.xlsx")
#        df.to_excel(excel_file_path, index=False, na_rep='-')
#        print("Comments saved to Excel.")

    return df

# %%
url = "https://www.lazada.co.th/products/24h-to-sendyouli-10pcs-pampers-i2804412437-s10218505636.html"
num_comments = 10
star_rating = 3
scrape_comments(url, num_comments, star_rating)
# Out:
# An error occurred while handling the slider: Message: no such window: target window already closed
# from unknown error: web view not found
#   (Session info: chrome=127.0.6533.120)
# Stacktrace:
# 0   chromedriver                        0x000000011017f8b8 chromedriver + 5179576
# 1   chromedriver                        0x00000001101772ea chromedriver + 5145322
# 2   chromedriver                        0x000000010fcee2b0 chromedriver + 389808
# 3   chromedriver                        0x000000010fcc5614 chromedriver + 222740
# 4   chromedriver                        0x000000010fd648ed chromedriver + 874733
# 5   chromedriver                        0x000000010fd794a9 chromedriver + 959657
# 6   chromedriver                        0x000000010fd5c553 chromedriver + 841043
# 7   chromedriver                        0x000000010fd2d7f6 chromedriver + 649206
# 8   chromedriver                        0x000000010fd2e05e chromedriver + 651358
# 9   chromedriver                        0x0000000110142b20 chromedriver + 4930336
# 10  chromedriver                        0x0000000110147a36 chromedriver + 4950582
# 11  chromedriver                        0x0000000110148105 chromedriver + 4952325
# 12  chromedriver                        0x0000000110124ee9 chromedriver + 4808425
# 13  chromedriver                        0x00000001101483f9 chromedriver + 4953081
# 14  chromedriver                        0x0000000110116844 chromedriver + 4749380
# 15  chromedriver                        0x00000001101675c8 chromedriver + 5080520
# 16  chromedriver                        0x0000000110167787 chromedriver + 5080967
# 17  chromedriver                        0x0000000110176ece chromedriver + 5144270
# 18  libsystem_pthread.dylib             0x00007fff207118fc _pthread_start + 224
# 19  libsystem_pthread.dylib             0x00007fff2070d443 thread_start + 15
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# Cell In[1226], line 4
#       2 num_comments = 10
#       3 star_rating = 3
# ----> 4 scrape_comments(url, num_comments, star_rating)
#
# Cell In[1224], line 11, in scrape_comments(url, num_comments, star_rating)
#       8 move_slider(driver)
#      10 # Check if the button exists
# ---> 11 button_exit = driver.find_elements(By.CLASS_NAME, "sfo__close")
#      12 if button_exit:
#      13     n = button_exit[0]
#
# File /opt/anaconda3/envs/user/lib/python3.12/site-packages/selenium/webdriver/remote/webdriver.py:778, in WebDriver.find_elements(self, by, value)
#     774     value = f'[name="{value}"]'
#     776 # Return empty list if driver returns null
#     777 # See https://github.com/SeleniumHQ/selenium/issues/4555
# --> 778 return self.execute(Command.FIND_ELEMENTS, {"using": by, "value": value})["value"] or []
#
# File /opt/anaconda3/envs/user/lib/python3.12/site-packages/selenium/webdriver/remote/webdriver.py:354, in WebDriver.execute(self, driver_command, params)
#     352 response = self.command_executor.execute(driver_command, params)
#     353 if response:
# --> 354     self.error_handler.check_response(response)
#     355     response["value"] = self._unwrap_value(response.get("value", None))
#     356     return response
#
# File /opt/anaconda3/envs/user/lib/python3.12/site-packages/selenium/webdriver/remote/errorhandler.py:229, in ErrorHandler.check_response(self, response)
#     227         alert_text = value["alert"].get("text")
#     228     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229 raise exception_class(message, screen, stacktrace)
#
# NoSuchWindowException: Message: no such window: target window already closed
# from unknown error: web view not found
#   (Session info: chrome=127.0.6533.120)
# Stacktrace:
# 0   chromedriver                        0x000000011017f8b8 chromedriver + 5179576
# 1   chromedriver                        0x00000001101772ea chromedriver + 5145322
# 2   chromedriver                        0x000000010fcee2b0 chromedriver + 389808
# 3   chromedriver                        0x000000010fcc5614 chromedriver + 222740
# 4   chromedriver                        0x000000010fd648ed chromedriver + 874733
# 5   chromedriver                        0x000000010fd794a9 chromedriver + 959657
# 6   chromedriver                        0x000000010fd5c553 chromedriver + 841043
# 7   chromedriver                        0x000000010fd2d7f6 chromedriver + 649206
# 8   chromedriver                        0x000000010fd2e05e chromedriver + 651358
# 9   chromedriver                        0x0000000110142b20 chromedriver + 4930336
# 10  chromedriver                        0x0000000110147a36 chromedriver + 4950582
# 11  chromedriver                        0x0000000110148105 chromedriver + 4952325
# 12  chromedriver                        0x0000000110124ee9 chromedriver + 4808425
# 13  chromedriver                        0x00000001101483f9 chromedriver + 4953081
# 14  chromedriver                        0x0000000110116844 chromedriver + 4749380
# 15  chromedriver                        0x00000001101675c8 chromedriver + 5080520
# 16  chromedriver                        0x0000000110167787 chromedriver + 5080967
# 17  chromedriver                        0x0000000110176ece chromedriver + 5144270
# 18  libsystem_pthread.dylib             0x00007fff207118fc _pthread_start + 224
# 19  libsystem_pthread.dylib             0x00007fff2070d443 thread_start + 15

# %%
#ผ่านการตรวจ

# %%
import undetected_chromedriver as uc 

def scrape_comments(urls, star_ratings, num_comments_list):
    all_comments = []
    #options = uc.ChromeOptions()
    
    Id_Item = 1  # Initialize the Id_Item
    
    for url, star_rating, num_comments in zip(urls, star_ratings, num_comments_list):
        if not isinstance(url, str):
            raise ValueError(f"URL must be a string, but got {type(url)}")
        
        driver = uc.Chrome(use_subprocess=False)
        driver.delete_all_cookies()
        driver.get(url)
        time.sleep(3)
        
        #move_slider(driver)  # Call the function to handle the slider if necessary
        
        # Close any popups or unwanted dialogs
        button_exit = driver.find_elements(By.CLASS_NAME, "sfo__close")
        if button_exit:
            button_exit[0].click()
        
        time.sleep(3)
        
        # Get the updated page source
        page_source = driver.page_source
        soup = BeautifulSoup(page_source, 'html.parser')
        
        h1_element = soup.find('div', class_='pdp-mod-product-badge-wrapper')
        thisitem = h1_element.text.strip() if h1_element else "Item not found"
        print("-------------------------------")
        print(f"Item : {thisitem}")
        
        h2_elements = soup.find_all('a', class_='pdp-link pdp-link_size_s pdp-link_theme_blue pdp-review-summary__link')
        quantity = h2_elements[0].text.strip() if h2_elements else "Quantity not found"
        quantity = quantity.replace("คะแนน", "").strip()
        print("-------------------------------")
        print(f"Quantity: {quantity}")

        SCROLL_PAUSE_TIME = 3
        scroll_increment = 400
        
        for star_rating, num_comments in zip(star_ratings, num_comments_list):
            driver.get(url)  # Reload the page for each star rating
            time.sleep(3)
            
            #move_slider(driver)  # Move slider if needed
            
            while True:
                driver.execute_script(f"window.scrollBy(0, {scroll_increment});")
                time.sleep(SCROLL_PAUSE_TIME)
                
                try:
                    filter_container = WebDriverWait(driver, 1).until(
                        EC.visibility_of_element_located((By.CLASS_NAME, "oper"))
                    )
                    filter_option = filter_container.find_element(By.XPATH, ".//span[@class='condition']")
                    if filter_option.is_displayed():
                        filter_option.click()
                        break
                except Exception as e:
                    print(f"Filter not found yet, continue scrolling... {e}")

                current_scroll_position = driver.execute_script("return window.scrollY;")
                total_height = driver.execute_script("return document.body.scrollHeight;")
                
                if current_scroll_position + scroll_increment >= total_height:
                    print("Reached the bottom of the page. Stopping scrolling.")
                    break
            
            time.sleep(3)

            if star_rating is not None:
                try:
                    star_filter_options = WebDriverWait(driver, 10).until(
                        EC.presence_of_element_located((By.CLASS_NAME, "next-menu-content"))
                    )
                    star_options = star_filter_options.find_elements(By.CLASS_NAME, "next-menu-item")
                    if 1 <= star_rating <= len(star_options):
                        star_options[6 - star_rating].click()
                    else:
                        print(f"Invalid star rating: {star_rating}")
                    time.sleep(5)
                    
                    try:
                        iframe = WebDriverWait(driver, 10).until(
                            EC.frame_to_be_available_and_switch_to_it((By.ID, "baxia-dialog-content"))
                        )
                        print("Switched to iframe.")
                        
                        try:
                            slider = WebDriverWait(driver, 10).until(
                                EC.visibility_of_element_located((By.CSS_SELECTOR, "span#nc_1_n1z.btn_slide"))
                            )
                            
                            action = ActionChains(driver)
                            action.click_and_hold(slider).perform()
                            
                            slider_width = driver.execute_script("return document.querySelector('span#nc_1_n1z.btn_slide').offsetWidth;")
                            container_width = driver.execute_script("return document.querySelector('span#nc_1_n1z.btn_slide').parentElement.offsetWidth;")
                            total_distance = container_width - slider_width
                            
                            # Parameters for movement with random ranges
                            min_step_size = 5
                            max_step_size = 25
                            min_pause_time = 0.01
                            max_pause_time = 0.5
                            min_acceleration = 1.2
                            max_acceleration = 5
                            
                            current_position = 0
                            
                            while current_position < total_distance:
                                step_size = random.randint(min_step_size, max_step_size)
                                pause_time = random.uniform(min_pause_time, max_pause_time)
                                acceleration = random.uniform(min_acceleration, max_acceleration)
                                
                                move = min(step_size, total_distance - current_position)
                                action.move_by_offset(move, 0).perform()
                                time.sleep(pause_time)
                                
                                current_position += move
                                pause_time = max(pause_time / acceleration, min_pause_time)
                            
                            # Release the slider after moving
                            time.sleep(2)
                            action.release().perform()
                            print("Slider has been moved smoothly.")
                            driver.switch_to.default_content()
                            handle_error(driver)
                        except Exception as e:
                            print(f"An error occurred while handling the slider: {e}")
                    
                    except Exception as e:
                        print(f"An error occurred while handling the iframe: {e}")

                except Exception as e:
                    print(f"An error occurred while managing star ratings or iframe: {e}")

            time.sleep(5)
            page_source = driver.page_source
            soup = BeautifulSoup(page_source, 'html.parser')
            
            comments = soup.find_all('div', class_='item')
            comment_data = []

            while len(comment_data) < num_comments:
                for comment in comments:
                    if len(comment_data) >= num_comments:
                        break
                    user_element = comment.find('div', class_='middle').find('span')
                    message_element = comment.find('div', class_='content')
                    
                    user = user_element.text.strip() if user_element else ""
                    content = message_element.text.strip() if message_element else ""
                    
                    sentiment = "Positive" if star_rating in [4, 5] else "Neutral" if star_rating == 3 else "Negative" if star_rating in [0, 1, 2] else "-"
                    
                    if user and content and is_valid_comment(content):
                        comment_data.append({'id': len(comment_data) + 1,'Id_Item': Id_Item,'Item': thisitem, 'Quantity': quantity, 'User': user, 'Message': content, 'Sentiment': sentiment, 'Star Rating': star_rating})
                        print(f"Comment {len(comment_data)}: {thisitem} - {quantity} - {user} - {content} - {sentiment} - {star_rating}")

                if len(comment_data) >= num_comments:
                    break
                
                SCROLL_PAUSE_TIME = 3
                scroll_increment = 200
                driver.execute_script(f"window.scrollBy(0, {scroll_increment});")
                time.sleep(SCROLL_PAUSE_TIME)
                
                try:
                    next_button = WebDriverWait(driver, 10).until(
                        EC.presence_of_element_located((By.CLASS_NAME, 'next'))
                    )
                    if next_button.is_enabled():
                        next_button.click()
                        time.sleep(5)
                        
                        try:
                            iframe = WebDriverWait(driver, 10).until(
                                EC.frame_to_be_available_and_switch_to_it((By.ID, "baxia-dialog-content"))
                            )
                            print("Switched to iframe.")
                            
                            try:
                                slider = WebDriverWait(driver, 10).until(
                                    EC.visibility_of_element_located((By.CSS_SELECTOR, "span#nc_1_n1z.btn_slide"))
                                )
                                
                                action = ActionChains(driver)
                                action.click_and_hold(slider).perform()
                                
                                slider_width = driver.execute_script("return document.querySelector('span#nc_1_n1z.btn_slide').offsetWidth;")
                                container_width = driver.execute_script("return document.querySelector('span#nc_1_n1z.btn_slide').parentElement.offsetWidth;")
                                total_distance = container_width - slider_width
                                
                                # Parameters for movement with random ranges
                                min_step_size = 5
                                max_step_size = 25
                                min_pause_time = 0.01
                                max_pause_time = 0.5
                                min_acceleration = 1.2
                                max_acceleration = 5
                                
                                current_position = 0
                                
                                while current_position < total_distance:
                                    step_size = random.randint(min_step_size, max_step_size)
                                    pause_time = random.uniform(min_pause_time, max_pause_time)
                                    acceleration = random.uniform(min_acceleration, max_acceleration)
                                    
                                    move = min(step_size, total_distance - current_position)
                                    action.move_by_offset(move, 0).perform()
                                    time.sleep(pause_time)
                                    
                                    current_position += move
                                    pause_time = max(pause_time / acceleration, min_pause_time)
                                
                                # Release the slider after moving
                                time.sleep(2)
                                action.release().perform()
                                print("Slider has been moved smoothly.")
                                driver.switch_to.default_content()
                                handle_error(driver)
                            except Exception as e:
                                print(f"An error occurred while handling the slider: {e}")
                            
                            page_source = driver.page_source
                            soup = BeautifulSoup(page_source, 'html.parser')
                            comments = soup.find_all('div', class_='item')
                            
                        except Exception as e:
                            print(f"An error occurred while handling the iframe: {e}")

                    else:
                        print("Next button is not enabled or not found. Exiting loop.")
                        break
                
                except Exception as e:
                    print(f"An error occurred while managing the 'next' button or overall process: {e}")
                    break
            
            all_comments.extend(comment_data)
    
    driver.quit()
    df = pd.DataFrame(all_comments)
    
    return df

# %%
#เก็บหลายเว็บและเก็บความคิดเห็นที่เป็นว่าง

# %%
def scrape_comments(urls, star_ratings, num_comments_list):
    all_comments = []
    comment_id = 1  # Initialize global comment ID

    for index, url in enumerate(urls):
        if not isinstance(url, str):
            raise ValueError(f"URL must be a string, but got {type(url)}")
        
        Id_Item = index + 1  # Use index to set Id_Item, starting from 1
        
        driver = uc.Chrome(use_subprocess=False)
        driver.delete_all_cookies()
        driver.get(url)
        time.sleep(3)
        
        # Close any popups or unwanted dialogs
        button_exit = driver.find_elements(By.CLASS_NAME, "sfo__close")
        if button_exit:
            button_exit[0].click()
        
        time.sleep(3)
        
        # Get the updated page source
        page_source = driver.page_source
        soup = BeautifulSoup(page_source, 'html.parser')
        
        h1_element = soup.find('div', class_='pdp-mod-product-badge-wrapper')
        thisitem = h1_element.text.strip() if h1_element else "Item not found"
        print("-------------------------------")
        print(f"Item : {thisitem}")
        
        h2_elements = soup.find_all('a', class_='pdp-link pdp-link_size_s pdp-link_theme_blue pdp-review-summary__link')
        quantity = h2_elements[0].text.strip() if h2_elements else "Quantity not found"
        quantity = quantity.replace("คะแนน", "").strip()
        print("-------------------------------")
        print(f"Quantity: {quantity}")

        for star_rating, num_comments in zip(star_ratings, num_comments_list):
            driver.get(url)  # Reload the page for each star rating
            time.sleep(3)
            
            # Scroll to reveal star filter options
            SCROLL_PAUSE_TIME = 3
            scroll_increment = 400
            
            while True:
                driver.execute_script(f"window.scrollBy(0, {scroll_increment});")
                time.sleep(SCROLL_PAUSE_TIME)
                
                try:
                    filter_container = WebDriverWait(driver, 1).until(
                        EC.visibility_of_element_located((By.CLASS_NAME, "oper"))
                    )
                    filter_option = filter_container.find_element(By.XPATH, ".//span[@class='condition']")
                    if filter_option.is_displayed():
                        filter_option.click()
                        break
                except Exception as e:
                    print(f"Filter not found yet, continue scrolling... {e}")

                current_scroll_position = driver.execute_script("return window.scrollY;")
                total_height = driver.execute_script("return document.body.scrollHeight;")
                
                if current_scroll_position + scroll_increment >= total_height:
                    print("Reached the bottom of the page. Stopping scrolling.")
                    break
            
            time.sleep(3)

            if star_rating is not None:
                try:
                    star_filter_options = WebDriverWait(driver, 10).until(
                        EC.presence_of_element_located((By.CLASS_NAME, "next-menu-content"))
                    )
                    star_options = star_filter_options.find_elements(By.CLASS_NAME, "next-menu-item")
                    if 1 <= star_rating <= len(star_options):
                        star_options[6 - star_rating].click()
                    else:
                        print(f"Invalid star rating: {star_rating}")
                    time.sleep(5)
                    
                    try:
                        iframe = WebDriverWait(driver, 10).until(
                            EC.frame_to_be_available_and_switch_to_it((By.ID, "baxia-dialog-content"))
                        )
                        print("Switched to iframe.")
                        
                        try:
                            slider = WebDriverWait(driver, 10).until(
                                EC.visibility_of_element_located((By.CSS_SELECTOR, "span#nc_1_n1z.btn_slide"))
                            )
                            
                            action = ActionChains(driver)
                            action.click_and_hold(slider).perform()
                            
                            slider_width = driver.execute_script("return document.querySelector('span#nc_1_n1z.btn_slide').offsetWidth;")
                            container_width = driver.execute_script("return document.querySelector('span#nc_1_n1z.btn_slide').parentElement.offsetWidth;")
                            total_distance = container_width - slider_width
                            
                            # Parameters for movement with wider random ranges
                            step_size = random.choice([5, 10, 15, 20, 25])
                            initial_pause_time = random.uniform(0.01, 0.5)
                            acceleration = random.uniform(1.2, 5)
                            
                            current_position = 0
                            pause_time = initial_pause_time
                            
                            while current_position < total_distance:
                                move = min(step_size, total_distance - current_position)
                                action.move_by_offset(move, 0).perform()
                                time.sleep(pause_time)
                                current_position += move
                                pause_time = max(pause_time / acceleration, 0.01)
                            time.sleep(2)
                            action.release().perform()
                            print("Slider has been moved smoothly.")
                            driver.switch_to.default_content()
                            handle_error(driver)
                        except Exception as e:
                            print(f"An error occurred while handling the slider: {e}")
                    
                    except Exception as e:
                        print(f"An error occurred while handling the iframe: {e}")

                except Exception as e:
                    print(f"An error occurred while managing star ratings or iframe: {e}")

            time.sleep(5)
            page_source = driver.page_source
            soup = BeautifulSoup(page_source, 'html.parser')
            
            comments = soup.find_all('div', class_='item')
            comment_data = []

            while len(comment_data) < num_comments:
                for comment in comments:
                    if len(comment_data) >= num_comments:
                        break
                    # หาว่า comment นี้มี div class='middle' หรือไม่
                    user_element = comment.find('div', class_='middle').find('span') if comment.find('div', class_='middle') else None
                    
                    # หาว่า comment นี้มี div class='content' หรือไม่
                    message_element = comment.find('div', class_='content')
                    
                    # กำหนดค่า user และ content ตามผลลัพธ์ที่หาเจอ
                    user = user_element.text.strip() if user_element else "ไม่มีชื่อ"
                    content = message_element.text.strip() if message_element else "ไม่มีข้อความ"
                    
                    sentiment = "Positive" if star_rating in [4, 5] else "Neutral" if star_rating == 3 else "Negative" if star_rating in [0, 1, 2] else "-"
                    
                    if user:
                        comment_data.append({
                            'id': comment_id,  # Use global comment_id
                            'Id_Item': Id_Item,
                            'Item': thisitem,
                            'Quantity': quantity,
                            'User': user,
                            'Message': content,
                            'Sentiment': sentiment,
                            'Star_rating': star_rating
                        })
                        print(f"Comment {comment_id}: {Id_Item} - {thisitem} - {quantity} - {user} - {content} - {sentiment} - {star_rating}")
                        
                        comment_id += 1  # Increment the global comment_id

                if len(comment_data) >= num_comments:
                    break
                
                driver.execute_script(f"window.scrollBy(0, {scroll_increment});")
                time.sleep(SCROLL_PAUSE_TIME)
                
                try:
                    next_button = WebDriverWait(driver, 40).until(
                        EC.presence_of_element_located((By.CLASS_NAME, 'next'))
                    )
                    if next_button.is_enabled():
                        next_button.click()
                        time.sleep(5)
                        try:
                            iframe = WebDriverWait(driver, 10).until(
                                EC.frame_to_be_available_and_switch_to_it((By.ID, "baxia-dialog-content"))
                            )
                            print("Switched to iframe.")
                            
                            try:
                                slider = WebDriverWait(driver, 10).until(
                                    EC.visibility_of_element_located((By.CSS_SELECTOR, "span#nc_1_n1z.btn_slide"))
                                )
                                
                                action = ActionChains(driver)
                                action.click_and_hold(slider).perform()
                                
                                slider_width = driver.execute_script("return document.querySelector('span#nc_1_n1z.btn_slide').offsetWidth;")
                                container_width = driver.execute_script("return document.querySelector('span#nc_1_n1z.btn_slide').parentElement.offsetWidth;")
                                total_distance = container_width - slider_width
                                
                                # Parameters for movement with wider random ranges
                                step_size = random.choice([5, 10, 15, 20, 25])  # Random step size from a broader range
                                initial_pause_time = random.uniform(0.01, 0.5)  # Random initial pause time between 0.01 and 0.5 seconds
                                acceleration = random.uniform(1.2, 5)  # Random acceleration factor between 1.2 and 5
                                
                                current_position = 0
                                pause_time = initial_pause_time
                                
                                while current_position < total_distance:
                                    move = min(step_size, total_distance - current_position)
                                    action.move_by_offset(move, 0).perform()
                                    time.sleep(pause_time)
                                    current_position += move
                                    pause_time = max(pause_time / acceleration, 0.01)
                                time.sleep(2)
                                action.release().perform()
                                print("Slider has been moved smoothly.")
                                driver.switch_to.default_content()
                                handle_error(driver)
                            except Exception as e:
                                print(f"An error occurred while handling the slider: {e}")
                            
                            page_source = driver.page_source
                            soup = BeautifulSoup(page_source, 'html.parser')
                            comments = soup.find_all('div', class_='item')
                            
                        except Exception as e:
                            print(f"An error occurred while handling the iframe: {e}")

                        page_source = driver.page_source
                        soup = BeautifulSoup(page_source, 'html.parser')
                        comments = soup.find_all('div', class_='item')
                    else:
                        print("Next button is not enabled or not found. Exiting loop.")
                        break
                
                except Exception as e:
                    print(f"An error occurred while managing the 'next' button or overall process: {e}")
                    break
            
            all_comments.extend(comment_data)
            
    driver.quit()
    df = pd.DataFrame(all_comments)
    
    return df

# %%
#เก็บความคิดเห็นเฉพาะที่มี ไม่เก็บที่ว่าง

# %%
def scrape_comments(urls, star_ratings, num_comments_list):
    all_comments = []
    comment_id = 1  # Initialize global comment ID

    for index, url in enumerate(urls):
        if not isinstance(url, str):
            raise ValueError(f"URL must be a string, but got {type(url)}")
        
        Id_Item = index + 1  # Use index to set Id_Item, starting from 1
        
        driver = uc.Chrome(use_subprocess=False)
        driver.delete_all_cookies()
        driver.get(url)
        time.sleep(3)
        
        # Close any popups or unwanted dialogs
        button_exit = driver.find_elements(By.CLASS_NAME, "sfo__close")
        if button_exit:
            button_exit[0].click()
        
        time.sleep(3)
        
        # Get the updated page source
        page_source = driver.page_source
        soup = BeautifulSoup(page_source, 'html.parser')
        
        h1_element = soup.find('div', class_='pdp-mod-product-badge-wrapper')
        thisitem = h1_element.text.strip() if h1_element else "Item not found"
        print("-------------------------------")
        print(f"Item : {thisitem}")
        
        h2_elements = soup.find_all('a', class_='pdp-link pdp-link_size_s pdp-link_theme_blue pdp-review-summary__link')
        quantity = h2_elements[0].text.strip() if h2_elements else "Quantity not found"
        quantity = quantity.replace("คะแนน", "").strip()
        print("-------------------------------")
        print(f"Quantity: {quantity}")

        for star_rating, num_comments in zip(star_ratings, num_comments_list):
            driver.get(url)  # Reload the page for each star rating
            time.sleep(3)
            
            # Scroll to reveal star filter options
            SCROLL_PAUSE_TIME = 3
            scroll_increment = 400
            
            while True:
                driver.execute_script(f"window.scrollBy(0, {scroll_increment});")
                time.sleep(SCROLL_PAUSE_TIME)
                
                try:
                    filter_container = WebDriverWait(driver, 1).until(
                        EC.visibility_of_element_located((By.CLASS_NAME, "oper"))
                    )
                    filter_option = filter_container.find_element(By.XPATH, ".//span[@class='condition']")
                    if filter_option.is_displayed():
                        filter_option.click()
                        break
                except Exception as e:
                    print(f"Filter not found yet, continue scrolling... {e}")

                current_scroll_position = driver.execute_script("return window.scrollY;")
                total_height = driver.execute_script("return document.body.scrollHeight;")
                
                if current_scroll_position + scroll_increment >= total_height:
                    print("Reached the bottom of the page. Stopping scrolling.")
                    break
            
            time.sleep(3)

            if star_rating is not None:
                try:
                    star_filter_options = WebDriverWait(driver, 10).until(
                        EC.presence_of_element_located((By.CLASS_NAME, "next-menu-content"))
                    )
                    star_options = star_filter_options.find_elements(By.CLASS_NAME, "next-menu-item")
                    if 1 <= star_rating <= len(star_options):
                        star_options[6 - star_rating].click()
                    else:
                        print(f"Invalid star rating: {star_rating}")
                    time.sleep(5)
                    
                    try:
                        iframe = WebDriverWait(driver, 10).until(
                            EC.frame_to_be_available_and_switch_to_it((By.ID, "baxia-dialog-content"))
                        )
                        print("Switched to iframe.")
                        
                        try:
                            slider = WebDriverWait(driver, 10).until(
                                EC.visibility_of_element_located((By.CSS_SELECTOR, "span#nc_1_n1z.btn_slide"))
                            )
                            
                            action = ActionChains(driver)
                            action.click_and_hold(slider).perform()
                            
                            slider_width = driver.execute_script("return document.querySelector('span#nc_1_n1z.btn_slide').offsetWidth;")
                            container_width = driver.execute_script("return document.querySelector('span#nc_1_n1z.btn_slide').parentElement.offsetWidth;")
                            total_distance = container_width - slider_width
                            
                            # Parameters for movement with wider random ranges
                            step_size = random.choice([5, 10, 15, 20, 25])
                            initial_pause_time = random.uniform(0.01, 0.5)
                            acceleration = random.uniform(1.2, 5)
                            
                            current_position = 0
                            pause_time = initial_pause_time
                            
                            while current_position < total_distance:
                                move = min(step_size, total_distance - current_position)
                                action.move_by_offset(move, 0).perform()
                                time.sleep(pause_time)
                                current_position += move
                                pause_time = max(pause_time / acceleration, 0.01)
                            time.sleep(2)
                            action.release().perform()
                            print("Slider has been moved smoothly.")
                            driver.switch_to.default_content()
                            handle_error(driver)
                        except Exception as e:
                            print(f"An error occurred while handling the slider: {e}")
                    
                    except Exception as e:
                        print(f"An error occurred while handling the iframe: {e}")

                except Exception as e:
                    print(f"An error occurred while managing star ratings or iframe: {e}")

            time.sleep(5)
            page_source = driver.page_source
            soup = BeautifulSoup(page_source, 'html.parser')
            
            comments = soup.find_all('div', class_='item')
            comment_data = []

            while len(comment_data) < num_comments:
                for comment in comments:
                    if len(comment_data) >= num_comments:
                        break
                    user_element = comment.find('div', class_='middle').find('span')
                    message_element = comment.find('div', class_='content')
                    
                    user = user_element.text.strip() if user_element else "ไม่มีชื่อ"
                    content = message_element.text.strip() if message_element else "ไม่มีข้อความ"
                    
                    sentiment = "Positive" if star_rating in [4, 5] else "Neutral" if star_rating == 3 else "Negative" if star_rating in [0, 1, 2] else "-"
                    
                    if user and content and is_valid_comment(content):
                        comment_data.append({
                            'id': comment_id,  # Use global comment_id
                            'Id_Item': Id_Item,
                            'Item': thisitem,
                            'Quantity': quantity,
                            'User': user,
                            'Message': content,
                            'Sentiment': sentiment,
                            'Star_rating': star_rating
                        })
                        print(f"Comment {comment_id}: {Id_Item} - {thisitem} - {quantity} - {user} - {content} - {sentiment} - {star_rating}")
                        
                        comment_id += 1  # Increment the global comment_id

                if len(comment_data) >= num_comments:
                    break
                
                driver.execute_script(f"window.scrollBy(0, {scroll_increment});")
                time.sleep(SCROLL_PAUSE_TIME)
                
                try:
                    next_button = WebDriverWait(driver, 40).until(
                        EC.presence_of_element_located((By.CLASS_NAME, 'next'))
                    )
                    if next_button.is_enabled():
                        next_button.click()
                        time.sleep(5)
                        try:
                            iframe = WebDriverWait(driver, 10).until(
                                EC.frame_to_be_available_and_switch_to_it((By.ID, "baxia-dialog-content"))
                            )
                            print("Switched to iframe.")
                            
                            try:
                                slider = WebDriverWait(driver, 10).until(
                                    EC.visibility_of_element_located((By.CSS_SELECTOR, "span#nc_1_n1z.btn_slide"))
                                )
                                
                                action = ActionChains(driver)
                                action.click_and_hold(slider).perform()
                                
                                slider_width = driver.execute_script("return document.querySelector('span#nc_1_n1z.btn_slide').offsetWidth;")
                                container_width = driver.execute_script("return document.querySelector('span#nc_1_n1z.btn_slide').parentElement.offsetWidth;")
                                total_distance = container_width - slider_width
                                
                                # Parameters for movement with wider random ranges
                                step_size = random.choice([5, 10, 15, 20, 25])  # Random step size from a broader range
                                initial_pause_time = random.uniform(0.01, 0.5)  # Random initial pause time between 0.01 and 0.5 seconds
                                acceleration = random.uniform(1.2, 5)  # Random acceleration factor between 1.2 and 5
                                
                                current_position = 0
                                pause_time = initial_pause_time
                                
                                while current_position < total_distance:
                                    move = min(step_size, total_distance - current_position)
                                    action.move_by_offset(move, 0).perform()
                                    time.sleep(pause_time)
                                    current_position += move
                                    pause_time = max(pause_time / acceleration, 0.01)
                                time.sleep(2)
                                action.release().perform()
                                print("Slider has been moved smoothly.")
                                driver.switch_to.default_content()
                                handle_error(driver)
                            except Exception as e:
                                print(f"An error occurred while handling the slider: {e}")
                            
                            page_source = driver.page_source
                            soup = BeautifulSoup(page_source, 'html.parser')
                            comments = soup.find_all('div', class_='item')
                            
                        except Exception as e:
                            print(f"An error occurred while handling the iframe: {e}")

                        page_source = driver.page_source
                        soup = BeautifulSoup(page_source, 'html.parser')
                        comments = soup.find_all('div', class_='item')
                    else:
                        print("Next button is not enabled or not found. Exiting loop.")
                        break
                
                except Exception as e:
                    print(f"An error occurred while managing the 'next' button or overall process: {e}")
                    break
            
            all_comments.extend(comment_data)
            
    driver.quit()
    df = pd.DataFrame(all_comments)
    
    return df

# %%
# Example data
urls = [
    'https://www.lazada.co.th/products/the-whispercod-10pcs-mlxl-i5072137207-s21416264761.html',
]

# Corresponding star ratings for each URL (example: 4-star and 5-star filters)
star_ratings = [5,4,3,1]  # Each URL might need different star ratings

# Corresponding number of comments to scrape for each star rating
num_comments_list = [555,9,7,2]  # Adjust based on your needs

# Call the function
df = scrape_comments(urls, star_ratings, num_comments_list)

# Display the resulting DataFrame
print(df)
# Out:
# -------------------------------
# Item : 【The whisper】COD ผ้าอ้อมผู้ใหญ่ 10PCS M/L/XL การดูดซับที่ดี รุ่นบางเบาระบายอากาศดี ใช้ได้ทั้งชายหญิง
# -------------------------------
# Quantity: 576
# An error occurred while handling the iframe: Message:
# Stacktrace:
# 0   undetected_chromedriver             0x000000010a4262a8 undetected_chromedriver + 5096104
# 1   undetected_chromedriver             0x000000010a41dada undetected_chromedriver + 5061338
# 2   undetected_chromedriver             0x0000000109fa8fd0 undetected_chromedriver + 389072
# 3   undetected_chromedriver             0x0000000109ff59ab undetected_chromedriver + 702891
# 4   undetected_chromedriver             0x0000000109ff5a81 undetected_chromedriver + 703105
# 5   undetected_chromedriver             0x000000010a039cd4 undetected_chromedriver + 982228
# 6   undetected_chromedriver             0x000000010a019f1d undetected_chromedriver + 851741
# 7   undetected_chromedriver             0x000000010a037250 undetected_chromedriver + 971344
# 8   undetected_chromedriver             0x000000010a019c93 undetected_chromedriver + 851091
# 9   undetected_chromedriver             0x0000000109fe8c79 undetected_chromedriver + 650361
# 10  undetected_chromedriver             0x0000000109fe949e undetected_chromedriver + 652446
# 11  undetected_chromedriver             0x000000010a3e9020 undetected_chromedriver + 4845600
# 12  undetected_chromedriver             0x000000010a3edf38 undetected_chromedriver + 4865848
# 13  undetected_chromedriver             0x000000010a3ee605 undetected_chromedriver + 4867589
# 14  undetected_chromedriver             0x000000010a3cbc59 undetected_chromedriver + 4725849
# 15  undetected_chromedriver             0x000000010a3ee8f9 undetected_chromedriver + 4868345
# 16  undetected_chromedriver             0x000000010a3bdb74 undetected_chromedriver + 4668276
# 17  undetected_chromedriver             0x000000010a40ddd8 undetected_chromedriver + 4996568
# 18  undetected_chromedriver             0x000000010a40dfd7 undetected_chromedriver + 4997079
# 19  undetected_chromedriver             0x000000010a41d6de undetected_chromedriver + 5060318
# 20  libsystem_pthread.dylib             0x00007fff203738fc _pthread_start + 224
# 21  libsystem_pthread.dylib             0x00007fff2036f443 thread_start + 15
#
# Comment 1: 1 - 【The whisper】COD ผ้าอ้อมผู้ใหญ่ 10PCS M/L/XL การดูดซับที่ดี รุ่นบางเบาระบายอากาศดี ใช้ได้ทั้งชายหญิง - 576 - *******333 - การป้องกันเอวสามมิติ, คุณภาพเยี่ยม, ผ้าหายใจได้, ล็อคปลอดภัย, นุ่มและอ่อนโยนต่อผิว, ความสามารถในการดูดซับที่ดี, - Positive - 5
# Comment 2: 1 - 【The whisper】COD ผ้าอ้อมผู้ใหญ่ 10PCS M/L/XL การดูดซับที่ดี รุ่นบางเบาระบายอากาศดี ใช้ได้ทั้งชายหญิง - 576 - นาง ส. - ขนาดกำลังดีนะเดี๋ยวจะลองใช้ดู รคาดีมากขนส่งเร็ววัสดุนิ่มน่าใช้จ้ะผ้าที่ระบายอากาศได้, การดูดซับที่ยอดเยี่ยม, คุณภาพยอดเยี่ยม, - Positive - 5
# Comment 3: 1 - 【The whisper】COD ผ้าอ้อมผู้ใหญ่ 10PCS M/L/XL การดูดซับที่ดี รุ่นบางเบาระบายอากาศดี ใช้ได้ทั้งชายหญิง - 576 - จิดาภา - การแห้งเร็ว, ผ้าหายใจได้, นุ่มและอ่อนโยนต่อผิว, นุ่มสบาย, การป้องกันการรั่วซึม, การออกแบบในสไตล์กางเกงขาสั้นที่สะดวกสบาย, - Positive - 5
# Comment 4: 1 - 【The whisper】COD ผ้าอ้อมผู้ใหญ่ 10PCS M/L/XL การดูดซับที่ดี รุ่นบางเบาระบายอากาศดี ใช้ได้ทั้งชายหญิง - 576 - คณารัตน์ ม. - ล็อคปลอดภัย, ความสามารถในการดูดซับที่ดี, คุณภาพเยี่ยม, การป้องกันเอวสามมิติ, นุ่มสบาย, นุ่มและอ่อนโยนต่อผิว, - Positive - 5
# Comment 5: 1 - 【The whisper】COD ผ้าอ้อมผู้ใหญ่ 10PCS M/L/XL การดูดซับที่ดี รุ่นบางเบาระบายอากาศดี ใช้ได้ทั้งชายหญิง - 576 - B***. - Quick drying, Leak-proof protection, Soft and gentle on the skin, Excellent quality, Great absorbency, - Positive - 5
# An error occurred while handling the iframe: Message:
# Stacktrace:
# 0   undetected_chromedriver             0x000000010a4262a8 undetected_chromedriver + 5096104
# 1   undetected_chromedriver             0x000000010a41dada undetected_chromedriver + 5061338
# 2   undetected_chromedriver             0x0000000109fa8fd0 undetected_chromedriver + 389072
# 3   undetected_chromedriver             0x0000000109ff59ab undetected_chromedriver + 702891
# 4   undetected_chromedriver             0x0000000109ff5a81 undetected_chromedriver + 703105
# 5   undetected_chromedriver             0x000000010a039cd4 undetected_chromedriver + 982228
# 6   undetected_chromedriver             0x000000010a019f1d undetected_chromedriver + 851741
# 7   undetected_chromedriver             0x000000010a037250 undetected_chromedriver + 971344
# 8   undetected_chromedriver             0x000000010a019c93 undetected_chromedriver + 851091
# 9   undetected_chromedriver             0x0000000109fe8c79 undetected_chromedriver + 650361
# 10  undetected_chromedriver             0x0000000109fe949e undetected_chromedriver + 652446
# 11  undetected_chromedriver             0x000000010a3e9020 undetected_chromedriver + 4845600
# 12  undetected_chromedriver             0x000000010a3edf38 undetected_chromedriver + 4865848
# 13  undetected_chromedriver             0x000000010a3ee605 undetected_chromedriver + 4867589
# 14  undetected_chromedriver             0x000000010a3cbc59 undetected_chromedriver + 4725849
# 15  undetected_chromedriver             0x000000010a3ee8f9 undetected_chromedriver + 4868345
# 16  undetected_chromedriver             0x000000010a3bdb74 undetected_chromedriver + 4668276
# 17  undetected_chromedriver             0x000000010a40ddd8 undetected_chromedriver + 4996568
# 18  undetected_chromedriver             0x000000010a40dfd7 undetected_chromedriver + 4997079
# 19  undetected_chromedriver             0x000000010a41d6de undetected_chromedriver + 5060318
# 20  libsystem_pthread.dylib             0x00007fff203738fc _pthread_start + 224
# 21  libsystem_pthread.dylib             0x00007fff2036f443 thread_start + 15
#
# Comment 6: 1 - 【The whisper】COD ผ้าอ้อมผู้ใหญ่ 10PCS M/L/XL การดูดซับที่ดี รุ่นบางเบาระบายอากาศดี ใช้ได้ทั้งชายหญิง - 576 - *******251 - การออกแบบในสไตล์กางเกงขาสั้นที่สะดวกสบาย, นุ่มและอ่อนโยนต่อผิว, การแห้งเร็ว, ล็อคปลอดภัย, คุณภาพเยี่ยม, - Positive - 5
# Comment 7: 1 - 【The whisper】COD ผ้าอ้อมผู้ใหญ่ 10PCS M/L/XL การดูดซับที่ดี รุ่นบางเบาระบายอากาศดี ใช้ได้ทั้งชายหญิง - 576 - xganx - ส่งไว ตรงปก ส่งไว ตรงปก ส่งไว ตรงปก
# ส่งไว ตรงปก ส่งไว ตรงปก ส่งไว ตรงปก
# ส่งไว ตรงปก ส่งไว ตรงปก ส่งไว ตรงปก
# ส่งไว ตรงปก ส่งไว ตรงปก ส่งไว ตรงปก - Positive - 5
# Comment 8: 1 - 【The whisper】COD ผ้าอ้อมผู้ใหญ่ 10PCS M/L/XL การดูดซับที่ดี รุ่นบางเบาระบายอากาศดี ใช้ได้ทั้งชายหญิง - 576 - น***. - การป้องกันการรั่วซึม, นุ่มสบาย, ผ้าหายใจได้, การออกแบบในสไตล์กางเกงขาสั้นที่สะดวกสบาย, การออกแบบในสไตล์กางเกงขาสั้นที่สะดวกสบาย, - Positive - 5
# Comment 9: 1 - 【The whisper】COD ผ้าอ้อมผู้ใหญ่ 10PCS M/L/XL การดูดซับที่ดี รุ่นบางเบาระบายอากาศดี ใช้ได้ทั้งชายหญิง - 576 - 9***2 - การออกแบบในสไตล์กางเกงขาสั้นที่สะดวกสบาย, การป้องกันเอวสามมิติ, นุ่มสบาย, ความสามารถในการดูดซับที่ดี, - Positive - 5
# Comment 10: 1 - 【The whisper】COD ผ้าอ้อมผู้ใหญ่ 10PCS M/L/XL การดูดซับที่ดี รุ่นบางเบาระบายอากาศดี ใช้ได้ทั้งชายหญิง - 576 - อัจฉรา เ. - การออกแบบในสไตล์กางเกงขาสั้นที่สะดวกสบาย, นุ่มสบาย, นุ่มและอ่อนโยนต่อผิว, การแห้งเร็ว, ความสามารถในการดูดซับที่ดี, - Positive - 5
# An error occurred while handling the iframe: Message:
# Stacktrace:
# 0   undetected_chromedriver             0x000000010a4262a8 undetected_chromedriver + 5096104
# 1   undetected_chromedriver             0x000000010a41dada undetected_chromedriver + 5061338
# 2   undetected_chromedriver             0x0000000109fa8fd0 undetected_chromedriver + 389072
# 3   undetected_chromedriver             0x0000000109ff59ab undetected_chromedriver + 702891
# 4   undetected_chromedriver             0x0000000109ff5a81 undetected_chromedriver + 703105
# 5   undetected_chromedriver             0x000000010a039cd4 undetected_chromedriver + 982228
# 6   undetected_chromedriver             0x000000010a019f1d undetected_chromedriver + 851741
# 7   undetected_chromedriver             0x000000010a037250 undetected_chromedriver + 971344
# 8   undetected_chromedriver             0x000000010a019c93 undetected_chromedriver + 851091
# 9   undetected_chromedriver             0x0000000109fe8c79 undetected_chromedriver + 650361
# 10  undetected_chromedriver             0x0000000109fe949e undetected_chromedriver + 652446
# 11  undetected_chromedriver             0x000000010a3e9020 undetected_chromedriver + 4845600
# 12  undetected_chromedriver             0x000000010a3edf38 undetected_chromedriver + 4865848
# 13  undetected_chromedriver             0x000000010a3ee605 undetected_chromedriver + 4867589
# 14  undetected_chromedriver             0x000000010a3cbc59 undetected_chromedriver + 4725849
# 15  undetected_chromedriver             0x000000010a3ee8f9 undetected_chromedriver + 4868345
# 16  undetected_chromedriver             0x000000010a3bdb74 undetected_chromedriver + 4668276
# 17  undetected_chromedriver             0x000000010a40ddd8 undetected_chromedriver + 4996568
# 18  undetected_chromedriver             0x000000010a40dfd7 undetected_chromedriver + 4997079
# 19  undetected_chromedriver             0x000000010a41d6de undetected_chromedriver + 5060318
# 20  libsystem_pthread.dylib             0x00007fff203738fc _pthread_start + 224
# 21  libsystem_pthread.dylib             0x00007fff2036f443 thread_start + 15
#
# Comment 11: 1 - 【The whisper】COD ผ้าอ้อมผู้ใหญ่ 10PCS M/L/XL การดูดซับที่ดี รุ่นบางเบาระบายอากาศดี ใช้ได้ทั้งชายหญิง - 576 - ประกายดาว ป. - ผ้าหายใจได้, การแห้งเร็ว, การป้องกันเอวสามมิติ, นุ่มและอ่อนโยนต่อผิว, ความสามารถในการดูดซับที่ดี, การออกแบบในสไตล์กางเกงขาสั้นที่สะดวกสบาย, ความสามารถในการดูดซับที่ดี, - Positive - 5
# Comment 12: 1 - 【The whisper】COD ผ้าอ้อมผู้ใหญ่ 10PCS M/L/XL การดูดซับที่ดี รุ่นบางเบาระบายอากาศดี ใช้ได้ทั้งชายหญิง - 576 - Nine - นุ่มสบาย, คุณภาพเยี่ยม, การป้องกันการรั่วซึม, นุ่มและอ่อนโยนต่อผิว, การแห้งเร็ว, การออกแบบในสไตล์กางเกงขาสั้นที่สะดวกสบาย, - Positive - 5
# Comment 13: 1 - 【The whisper】COD ผ้าอ้อมผู้ใหญ่ 10PCS M/L/XL การดูดซับที่ดี รุ่นบางเบาระบายอากาศดี ใช้ได้ทั้งชายหญิง - 576 - รริดาารรณ - พึ่งได้รับยังไม่ทดลองใช้ แต่คิดว่าน่าจะดีนะ ขนาดเท่ากับยี่ห้ออื่น ซับได้อยู่แต่ต้องค่อยๆเปลี่ยน เหมาะสำหรับผู้สูงอายุ ดีคะ ไซด์M ถูกต้องในห่อมี 10ชิ้นครบ ไว้จะซื้ออีก แนะนำร้านนี้คะ ตรงปก - Positive - 5
# Comment 14: 1 - 【The whisper】COD ผ้าอ้อมผู้ใหญ่ 10PCS M/L/XL การดูดซับที่ดี รุ่นบางเบาระบายอากาศดี ใช้ได้ทั้งชายหญิง - 576 - ฤดี - ตอนนี้ซื้อมาลองหลายยี่ห้อมาก  จะหาให้พอดีกับคนใช้ ไม่รู้จะถูกใจที่ยี่ห้อไหน  ยี่ห้อนี้ยังไม่ได้แกะลอง - Positive - 5
# Comment 15: 1 - 【The whisper】COD ผ้าอ้อมผู้ใหญ่ 10PCS M/L/XL การดูดซับที่ดี รุ่นบางเบาระบายอากาศดี ใช้ได้ทั้งชายหญิง - 576 - Nine - การป้องกันการรั่วซึม, การออกแบบสไตล์กางเกงที่สะดวกสบาย, นุ่มและอ่อนโยนต่อผิว, แห้งเร็ว, ผ้าที่ระบายอากาศได้, - Positive - 5
# An error occurred while handling the iframe: Message:
# Stacktrace:
# 0   undetected_chromedriver             0x000000010a4262a8 undetected_chromedriver + 5096104
# 1   undetected_chromedriver             0x000000010a41dada undetected_chromedriver + 5061338
# 2   undetected_chromedriver             0x0000000109fa8fd0 undetected_chromedriver + 389072
# 3   undetected_chromedriver             0x0000000109ff59ab undetected_chromedriver + 702891
# 4   undetected_chromedriver             0x0000000109ff5a81 undetected_chromedriver + 703105
# 5   undetected_chromedriver             0x000000010a039cd4 undetected_chromedriver + 982228
# 6   undetected_chromedriver             0x000000010a019f1d undetected_chromedriver + 851741
# 7   undetected_chromedriver             0x000000010a037250 undetected_chromedriver + 971344
# 8   undetected_chromedriver             0x000000010a019c93 undetected_chromedriver + 851091
# 9   undetected_chromedriver             0x0000000109fe8c79 undetected_chromedriver + 650361
# 10  undetected_chromedriver             0x0000000109fe949e undetected_chromedriver + 652446
# 11  undetected_chromedriver             0x000000010a3e9020 undetected_chromedriver + 4845600
# 12  undetected_chromedriver             0x000000010a3edf38 undetected_chromedriver + 4865848
# 13  undetected_chromedriver             0x000000010a3ee605 undetected_chromedriver + 4867589
# 14  undetected_chromedriver             0x000000010a3cbc59 undetected_chromedriver + 4725849
# 15  undetected_chromedriver             0x000000010a3ee8f9 undetected_chromedriver + 4868345
# 16  undetected_chromedriver             0x000000010a3bdb74 undetected_chromedriver + 4668276
# 17  undetected_chromedriver             0x000000010a40ddd8 undetected_chromedriver + 4996568
# 18  undetected_chromedriver             0x000000010a40dfd7 undetected_chromedriver + 4997079
# 19  undetected_chromedriver             0x000000010a41d6de undetected_chromedriver + 5060318
# 20  libsystem_pthread.dylib             0x00007fff203738fc _pthread_start + 224
# 21  libsystem_pthread.dylib             0x00007fff2036f443 thread_start + 15
#
# Comment 16: 1 - 【The whisper】COD ผ้าอ้อมผู้ใหญ่ 10PCS M/L/XL การดูดซับที่ดี รุ่นบางเบาระบายอากาศดี ใช้ได้ทั้งชายหญิง - 576 - Sane Y. - I like the product. The quality is so good. High-quality. Best price. The seller is fast so is the delivery. - Positive - 5
# Comment 17: 1 - 【The whisper】COD ผ้าอ้อมผู้ใหญ่ 10PCS M/L/XL การดูดซับที่ดี รุ่นบางเบาระบายอากาศดี ใช้ได้ทั้งชายหญิง - 576 - B***. - Soft and comfortable, Great absorbency, Soft and gentle on the skin, Secure lock, Excellent quality, Convenient pant-style design, - Positive - 5
# Comment 18: 1 - 【The whisper】COD ผ้าอ้อมผู้ใหญ่ 10PCS M/L/XL การดูดซับที่ดี รุ่นบางเบาระบายอากาศดี ใช้ได้ทั้งชายหญิง - 576 - กาญจนา - ผ้าที่ระบายอากาศได้, การป้องกันเอวสามมิติ, ล็อคที่ปลอดภัย, แห้งเร็ว, นุ่มและสบาย, นุ่มและอ่อนโยนต่อผิว, นุ่มและสบาย, การป้องกันเอวสามมิติ, - Positive - 5
# Comment 19: 1 - 【The whisper】COD ผ้าอ้อมผู้ใหญ่ 10PCS M/L/XL การดูดซับที่ดี รุ่นบางเบาระบายอากาศดี ใช้ได้ทั้งชายหญิง - 576 - Moo - ผ้าหายใจได้, การป้องกันเอวสามมิติ, การออกแบบในสไตล์กางเกงขาสั้นที่สะดวกสบาย, การออกแบบในสไตล์กางเกงขาสั้นที่สะดวกสบาย, - Positive - 5
# Comment 20: 1 - 【The whisper】COD ผ้าอ้อมผู้ใหญ่ 10PCS M/L/XL การดูดซับที่ดี รุ่นบางเบาระบายอากาศดี ใช้ได้ทั้งชายหญิง - 576 - C***. - นุ่มและอ่อนโยนต่อผิว, ความสามารถในการดูดซับที่ดี, นุ่มสบาย, การป้องกันเอวสามมิติ, การป้องกันเอวสามมิติ, การป้องกันเอวสามมิติ, - Positive - 5
# An error occurred while handling the iframe: Message:
# Stacktrace:
# 0   undetected_chromedriver             0x000000010a4262a8 undetected_chromedriver + 5096104
# 1   undetected_chromedriver             0x000000010a41dada undetected_chromedriver + 5061338
# 2   undetected_chromedriver             0x0000000109fa8fd0 undetected_chromedriver + 389072
# 3   undetected_chromedriver             0x0000000109ff59ab undetected_chromedriver + 702891
# 4   undetected_chromedriver             0x0000000109ff5a81 undetected_chromedriver + 703105
# 5   undetected_chromedriver             0x000000010a039cd4 undetected_chromedriver + 982228
# 6   undetected_chromedriver             0x000000010a019f1d undetected_chromedriver + 851741
# 7   undetected_chromedriver             0x000000010a037250 undetected_chromedriver + 971344
# 8   undetected_chromedriver             0x000000010a019c93 undetected_chromedriver + 851091
# 9   undetected_chromedriver             0x0000000109fe8c79 undetected_chromedriver + 650361
# 10  undetected_chromedriver             0x0000000109fe949e undetected_chromedriver + 652446
# 11  undetected_chromedriver             0x000000010a3e9020 undetected_chromedriver + 4845600
# 12  undetected_chromedriver             0x000000010a3edf38 undetected_chromedriver + 4865848
# 13  undetected_chromedriver             0x000000010a3ee605 undetected_chromedriver + 4867589
# 14  undetected_chromedriver             0x000000010a3cbc59 undetected_chromedriver + 4725849
# 15  undetected_chromedriver             0x000000010a3ee8f9 undetected_chromedriver + 4868345
# 16  undetected_chromedriver             0x000000010a3bdb74 undetected_chromedriver + 4668276
# 17  undetected_chromedriver             0x000000010a40ddd8 undetected_chromedriver + 4996568
# 18  undetected_chromedriver             0x000000010a40dfd7 undetected_chromedriver + 4997079
# 19  undetected_chromedriver             0x000000010a41d6de undetected_chromedriver + 5060318
# 20  libsystem_pthread.dylib             0x00007fff203738fc _pthread_start + 224
# 21  libsystem_pthread.dylib             0x00007fff2036f443 thread_start + 15
#
# Comment 21: 1 - 【The whisper】COD ผ้าอ้อมผู้ใหญ่ 10PCS M/L/XL การดูดซับที่ดี รุ่นบางเบาระบายอากาศดี ใช้ได้ทั้งชายหญิง - 576 - 0***6 - ยังไม่ได้ลองใช้  ต้องลองดูก่อนว่าดีไหม แต่ส่งเร็วมาก ห่อมาดีใช้ได้ ถ้าดีจะสั่งอีก แต่ดูหีบห่ออาจจะดี - Positive - 5
# Comment 22: 1 - 【The whisper】COD ผ้าอ้อมผู้ใหญ่ 10PCS M/L/XL การดูดซับที่ดี รุ่นบางเบาระบายอากาศดี ใช้ได้ทั้งชายหญิง - 576 - b***k - ได้รับสินค้าครบถ้วนตรงตามที่สั่ง
# สินค้าคุณภาพดี คุ้มค่ากับราคา
# สินค้าบรรจุมาอย่างดี
# สินค้าไม่เสียหายสามารถใช้งานได้ตามปกติ
# พนักงานขนส่งบริการดี
# ความเร็วในการจัดส่งปกติ - Positive - 5
# Comment 23: 1 - 【The whisper】COD ผ้าอ้อมผู้ใหญ่ 10PCS M/L/XL การดูดซับที่ดี รุ่นบางเบาระบายอากาศดี ใช้ได้ทั้งชายหญิง - 576 - B***. - Quick drying, Great absorbency, Excellent quality, Soft and comfortable, Soft and gentle on the skin, - Positive - 5
# Comment 24: 1 - 【The whisper】COD ผ้าอ้อมผู้ใหญ่ 10PCS M/L/XL การดูดซับที่ดี รุ่นบางเบาระบายอากาศดี ใช้ได้ทั้งชายหญิง - 576 - S***. - ผ้าที่ระบายอากาศได้, นุ่มและอ่อนโยนต่อผิว, การออกแบบสไตล์กางเกงที่สะดวกสบาย, ต้องลองใช้จึงจะบอกเกี่ยวกับคุณภาพการซึมซับ - Positive - 5
# Comment 25: 1 - 【The whisper】COD ผ้าอ้อมผู้ใหญ่ 10PCS M/L/XL การดูดซับที่ดี รุ่นบางเบาระบายอากาศดี ใช้ได้ทั้งชายหญิง - 576 - Manit T. - นุ่มและอ่อนโยนต่อผิว, การป้องกันเอวสามมิติ, คุณภาพเยี่ยม, ล็อคปลอดภัย, ผ้าหายใจได้, ความสามารถในการดูดซับที่ดี, - Positive - 5
# An error occurred while handling the iframe: Message:
# Stacktrace:
# 0   undetected_chromedriver             0x000000010a4262a8 undetected_chromedriver + 5096104
# 1   undetected_chromedriver             0x000000010a41dada undetected_chromedriver + 5061338
# 2   undetected_chromedriver             0x0000000109fa8fd0 undetected_chromedriver + 389072
# 3   undetected_chromedriver             0x0000000109ff59ab undetected_chromedriver + 702891
# 4   undetected_chromedriver             0x0000000109ff5a81 undetected_chromedriver + 703105
# 5   undetected_chromedriver             0x000000010a039cd4 undetected_chromedriver + 982228
# 6   undetected_chromedriver             0x000000010a019f1d undetected_chromedriver + 851741
# 7   undetected_chromedriver             0x000000010a037250 undetected_chromedriver + 971344
# 8   undetected_chromedriver             0x000000010a019c93 undetected_chromedriver + 851091
# 9   undetected_chromedriver             0x0000000109fe8c79 undetected_chromedriver + 650361
# 10  undetected_chromedriver             0x0000000109fe949e undetected_chromedriver + 652446
# 11  undetected_chromedriver             0x000000010a3e9020 undetected_chromedriver + 4845600
# 12  undetected_chromedriver             0x000000010a3edf38 undetected_chromedriver + 4865848
# 13  undetected_chromedriver             0x000000010a3ee605 undetected_chromedriver + 4867589
# 14  undetected_chromedriver             0x000000010a3cbc59 undetected_chromedriver + 4725849
# 15  undetected_chromedriver             0x000000010a3ee8f9 undetected_chromedriver + 4868345
# 16  undetected_chromedriver             0x000000010a3bdb74 undetected_chromedriver + 4668276
# 17  undetected_chromedriver             0x000000010a40ddd8 undetected_chromedriver + 4996568
# 18  undetected_chromedriver             0x000000010a40dfd7 undetected_chromedriver + 4997079
# 19  undetected_chromedriver             0x000000010a41d6de undetected_chromedriver + 5060318
# 20  libsystem_pthread.dylib             0x00007fff203738fc _pthread_start + 224
# 21  libsystem_pthread.dylib             0x00007fff2036f443 thread_start + 15
#
# Comment 26: 1 - 【The whisper】COD ผ้าอ้อมผู้ใหญ่ 10PCS M/L/XL การดูดซับที่ดี รุ่นบางเบาระบายอากาศดี ใช้ได้ทั้งชายหญิง - 576 - อัจฉรา เ. - ล็อคปลอดภัย, การออกแบบในสไตล์กางเกงขาสั้นที่สะดวกสบาย, ความสามารถในการดูดซับที่ดี, การป้องกันเอวสามมิติ, การแห้งเร็ว, - Positive - 5
# Comment 27: 1 - 【The whisper】COD ผ้าอ้อมผู้ใหญ่ 10PCS M/L/XL การดูดซับที่ดี รุ่นบางเบาระบายอากาศดี ใช้ได้ทั้งชายหญิง - 576 - สุภาวดี ผ. - สินค้าคุณภาพดี ราคาย่อม ไม่แพง ชอบๆ การร้านค้าดี การให้บริการขนส่งดี สบาย ไม่ต้องไปซื้อเอง ชอบมาก ชอบที่สุดเลย - Positive - 5
# Comment 28: 1 - 【The whisper】COD ผ้าอ้อมผู้ใหญ่ 10PCS M/L/XL การดูดซับที่ดี รุ่นบางเบาระบายอากาศดี ใช้ได้ทั้งชายหญิง - 576 - Nine - การดูดซับที่ยอดเยี่ยม, ผ้าที่ระบายอากาศได้, นุ่มและอ่อนโยนต่อผิว, ล็อคที่ปลอดภัย, การออกแบบสไตล์กางเกงที่สะดวกสบาย, - Positive - 5
# Comment 29: 1 - 【The whisper】COD ผ้าอ้อมผู้ใหญ่ 10PCS M/L/XL การดูดซับที่ดี รุ่นบางเบาระบายอากาศดี ใช้ได้ทั้งชายหญิง - 576 - Ting N. - นุ่มสบาย, ล็อคปลอดภัย, คุณภาพเยี่ยม, ความสามารถในการดูดซับที่ดี, ผ้าหายใจได้, การป้องกันการรั่วซึม, การออกแบบในสไตล์กางเกงขาสั้นที่สะดวกสบาย, - Positive - 5
# Comment 30: 1 - 【The whisper】COD ผ้าอ้อมผู้ใหญ่ 10PCS M/L/XL การดูดซับที่ดี รุ่นบางเบาระบายอากาศดี ใช้ได้ทั้งชายหญิง - 576 - สรชา​ เ. - ได้รับสินค้าไวมากแต่ยังไม่ได้ทดลองใช้ถ้าใช้ดีแล้วจะมาบอกต่อนะคะราคาถูก  น้ำหนักเบาแต่ไม่ได้บอกว่าซึมซับได้กี่ml - Positive - 5
# An error occurred while handling the iframe: Message:
# Stacktrace:
# 0   undetected_chromedriver             0x000000010a4262a8 undetected_chromedriver + 5096104
# 1   undetected_chromedriver             0x000000010a41dada undetected_chromedriver + 5061338
# 2   undetected_chromedriver             0x0000000109fa8fd0 undetected_chromedriver + 389072
# 3   undetected_chromedriver             0x0000000109ff59ab undetected_chromedriver + 702891
# 4   undetected_chromedriver             0x0000000109ff5a81 undetected_chromedriver + 703105
# 5   undetected_chromedriver             0x000000010a039cd4 undetected_chromedriver + 982228
# 6   undetected_chromedriver             0x000000010a019f1d undetected_chromedriver + 851741
# 7   undetected_chromedriver             0x000000010a037250 undetected_chromedriver + 971344
# 8   undetected_chromedriver             0x000000010a019c93 undetected_chromedriver + 851091
# 9   undetected_chromedriver             0x0000000109fe8c79 undetected_chromedriver + 650361
# 10  undetected_chromedriver             0x0000000109fe949e undetected_chromedriver + 652446
# 11  undetected_chromedriver             0x000000010a3e9020 undetected_chromedriver + 4845600
# 12  undetected_chromedriver             0x000000010a3edf38 undetected_chromedriver + 4865848
# 13  undetected_chromedriver             0x000000010a3ee605 undetected_chromedriver + 4867589
# 14  undetected_chromedriver             0x000000010a3cbc59 undetected_chromedriver + 4725849
# 15  undetected_chromedriver             0x000000010a3ee8f9 undetected_chromedriver + 4868345
# 16  undetected_chromedriver             0x000000010a3bdb74 undetected_chromedriver + 4668276
# 17  undetected_chromedriver             0x000000010a40ddd8 undetected_chromedriver + 4996568
# 18  undetected_chromedriver             0x000000010a40dfd7 undetected_chromedriver + 4997079
# 19  undetected_chromedriver             0x000000010a41d6de undetected_chromedriver + 5060318
# 20  libsystem_pthread.dylib             0x00007fff203738fc _pthread_start + 224
# 21  libsystem_pthread.dylib             0x00007fff2036f443 thread_start + 15
#
# Comment 31: 1 - 【The whisper】COD ผ้าอ้อมผู้ใหญ่ 10PCS M/L/XL การดูดซับที่ดี รุ่นบางเบาระบายอากาศดี ใช้ได้ทั้งชายหญิง - 576 - 0***9 - นุ่มและอ่อนโยนต่อผิว, การป้องกันการรั่วซึม, การป้องกันเอวสามมิติ, ความสามารถในการดูดซับที่ดี,  เหมาะพอดี - Positive - 5
# Comment 32: 1 - 【The whisper】COD ผ้าอ้อมผู้ใหญ่ 10PCS M/L/XL การดูดซับที่ดี รุ่นบางเบาระบายอากาศดี ใช้ได้ทั้งชายหญิง - 576 - ณัชติยาภรณ์ ฯ. - นุ่มและอ่อนโยนต่อผิว, การออกแบบในสไตล์กางเกงขาสั้นที่สะดวกสบาย, นุ่มและอ่อนโยนต่อผิว, การแห้งเร็ว, การแห้งเร็ว, ผ้าหายใจได้, นุ่มและอ่อนโยนต่อผิว, ล็อคปลอดภัย, - Positive - 5
# Comment 33: 1 - 【The whisper】COD ผ้าอ้อมผู้ใหญ่ 10PCS M/L/XL การดูดซับที่ดี รุ่นบางเบาระบายอากาศดี ใช้ได้ทั้งชายหญิง - 576 - G***a - การป้องกันเอวสามมิติ, การป้องกันการรั่วซึม, คุณภาพเยี่ยม, นุ่มสบาย, การแห้งเร็ว, การออกแบบในสไตล์กางเกงขาสั้นที่สะดวกสบาย, - Positive - 5
# Comment 34: 1 - 【The whisper】COD ผ้าอ้อมผู้ใหญ่ 10PCS M/L/XL การดูดซับที่ดี รุ่นบางเบาระบายอากาศดี ใช้ได้ทั้งชายหญิง - 576 - 9***2 - จัดส่งเร็วดีค่ะการป้องกันเอวสามมิติ, ความสามารถในการดูดซับที่ดี, นุ่มสบาย, การป้องกันการรั่วซึม, คุณภาพเยี่ยม, - Positive - 5
# Comment 35: 1 - 【The whisper】COD ผ้าอ้อมผู้ใหญ่ 10PCS M/L/XL การดูดซับที่ดี รุ่นบางเบาระบายอากาศดี ใช้ได้ทั้งชายหญิง - 576 - นภาพร ร. - สั่งให้แม่ที่ต่างจังหวัดคุณภาพเยี่ยม, การออกแบบในสไตล์กางเกงขาสั้นที่สะดวกสบาย, นุ่มสบาย, ตอนนี้กำลังจะสั่งไซส์ m เพราะ l ใหญ่ไปนิดนึง
# ได้รับเร็วมากสั่งวันนี้พรุ่งนี้ได้เลยค่ะ - Positive - 5
# An error occurred while handling the iframe: Message:
# Stacktrace:
# 0   undetected_chromedriver             0x000000010a4262a8 undetected_chromedriver + 5096104
# 1   undetected_chromedriver             0x000000010a41dada undetected_chromedriver + 5061338
# 2   undetected_chromedriver             0x0000000109fa8fd0 undetected_chromedriver + 389072
# 3   undetected_chromedriver             0x0000000109ff59ab undetected_chromedriver + 702891
# 4   undetected_chromedriver             0x0000000109ff5a81 undetected_chromedriver + 703105
# 5   undetected_chromedriver             0x000000010a039cd4 undetected_chromedriver + 982228
# 6   undetected_chromedriver             0x000000010a019f1d undetected_chromedriver + 851741
# 7   undetected_chromedriver             0x000000010a037250 undetected_chromedriver + 971344
# 8   undetected_chromedriver             0x000000010a019c93 undetected_chromedriver + 851091
# 9   undetected_chromedriver             0x0000000109fe8c79 undetected_chromedriver + 650361
# 10  undetected_chromedriver             0x0000000109fe949e undetected_chromedriver + 652446
# 11  undetected_chromedriver             0x000000010a3e9020 undetected_chromedriver + 4845600
# 12  undetected_chromedriver             0x000000010a3edf38 undetected_chromedriver + 4865848
# 13  undetected_chromedriver             0x000000010a3ee605 undetected_chromedriver + 4867589
# 14  undetected_chromedriver             0x000000010a3cbc59 undetected_chromedriver + 4725849
# 15  undetected_chromedriver             0x000000010a3ee8f9 undetected_chromedriver + 4868345
# 16  undetected_chromedriver             0x000000010a3bdb74 undetected_chromedriver + 4668276
# 17  undetected_chromedriver             0x000000010a40ddd8 undetected_chromedriver + 4996568
# 18  undetected_chromedriver             0x000000010a40dfd7 undetected_chromedriver + 4997079
# 19  undetected_chromedriver             0x000000010a41d6de undetected_chromedriver + 5060318
# 20  libsystem_pthread.dylib             0x00007fff203738fc _pthread_start + 224
# 21  libsystem_pthread.dylib             0x00007fff2036f443 thread_start + 15
#
# Comment 36: 1 - 【The whisper】COD ผ้าอ้อมผู้ใหญ่ 10PCS M/L/XL การดูดซับที่ดี รุ่นบางเบาระบายอากาศดี ใช้ได้ทั้งชายหญิง - 576 - B***. - Leak-proof protection, Soft and gentle on the skin, Excellent quality, Great absorbency, Great absorbency, - Positive - 5
# Comment 37: 1 - 【The whisper】COD ผ้าอ้อมผู้ใหญ่ 10PCS M/L/XL การดูดซับที่ดี รุ่นบางเบาระบายอากาศดี ใช้ได้ทั้งชายหญิง - 576 - มู๋เบิร์ดกะมู๋ตี้ แ. - สินค้าตรงตามที่ลงไว้สินค้าดีมีคุณภาพแพ็คสินค้าดีพนักงานขนส่งยอดเยี่ยมขนาดและรายละเอียดตรงตามที่สั่ง - Positive - 5
# Comment 38: 1 - 【The whisper】COD ผ้าอ้อมผู้ใหญ่ 10PCS M/L/XL การดูดซับที่ดี รุ่นบางเบาระบายอากาศดี ใช้ได้ทั้งชายหญิง - 576 - ศศวิน ป. - ขอเสียไม่ส่งฟรี ต้องซื้อสินค้าพ่วงถึงจะส่งฟรี ในขณะที่ ยี่ห้ออื่น อีก 3 ยี่ห้อส่งฟรีหมด ยังไม่รู้ว่าจะใช้ดีหรือไม่เพราะยังไม่เคยลองใช้ แต่ถ้าดี แล้วมีส่งฟรีก็คงจะสั่งมาใช้อีกเรื่อยๆ แต่ถ้าไม่มีส่งฟรีก็คงต้องเลือกยี่ห้ออื่นที่ส่งฟรีเพราะมันไม่น่าจะแตกต่างกันมากมาย - Positive - 5
# Comment 39: 1 - 【The whisper】COD ผ้าอ้อมผู้ใหญ่ 10PCS M/L/XL การดูดซับที่ดี รุ่นบางเบาระบายอากาศดี ใช้ได้ทั้งชายหญิง - 576 - วรนุช น. - การออกแบบสไตล์กางเกงที่สะดวกสบาย, แห้งเร็ว, การป้องกันเอวสามมิติ, คุณภาพยอดเยี่ยม, การดูดซับที่ยอดเยี่ยม, ผ้าที่ระบายอากาศได้, ล็อคที่ปลอดภัย, - Positive - 5
# Comment 40: 1 - 【The whisper】COD ผ้าอ้อมผู้ใหญ่ 10PCS M/L/XL การดูดซับที่ดี รุ่นบางเบาระบายอากาศดี ใช้ได้ทั้งชายหญิง - 576 - 6***4 - ผ้าหายใจได้, คุณภาพเยี่ยม, การแห้งเร็ว, นุ่มและอ่อนโยนต่อผิว, ล็อคปลอดภัย, นุ่มสบาย, การออกแบบในสไตล์กางเกงขาสั้นที่สะดวกสบาย, - Positive - 5
# An error occurred while handling the iframe: Message:
# Stacktrace:
# 0   undetected_chromedriver             0x000000010a4262a8 undetected_chromedriver + 5096104
# 1   undetected_chromedriver             0x000000010a41dada undetected_chromedriver + 5061338
# 2   undetected_chromedriver             0x0000000109fa8fd0 undetected_chromedriver + 389072
# 3   undetected_chromedriver             0x0000000109ff59ab undetected_chromedriver + 702891
# 4   undetected_chromedriver             0x0000000109ff5a81 undetected_chromedriver + 703105
# 5   undetected_chromedriver             0x000000010a039cd4 undetected_chromedriver + 982228
# 6   undetected_chromedriver             0x000000010a019f1d undetected_chromedriver + 851741
# 7   undetected_chromedriver             0x000000010a037250 undetected_chromedriver + 971344
# 8   undetected_chromedriver             0x000000010a019c93 undetected_chromedriver + 851091
# 9   undetected_chromedriver             0x0000000109fe8c79 undetected_chromedriver + 650361
# 10  undetected_chromedriver             0x0000000109fe949e undetected_chromedriver + 652446
# 11  undetected_chromedriver             0x000000010a3e9020 undetected_chromedriver + 4845600
# 12  undetected_chromedriver             0x000000010a3edf38 undetected_chromedriver + 4865848
# 13  undetected_chromedriver             0x000000010a3ee605 undetected_chromedriver + 4867589
# 14  undetected_chromedriver             0x000000010a3cbc59 undetected_chromedriver + 4725849
# 15  undetected_chromedriver             0x000000010a3ee8f9 undetected_chromedriver + 4868345
# 16  undetected_chromedriver             0x000000010a3bdb74 undetected_chromedriver + 4668276
# 17  undetected_chromedriver             0x000000010a40ddd8 undetected_chromedriver + 4996568
# 18  undetected_chromedriver             0x000000010a40dfd7 undetected_chromedriver + 4997079
# 19  undetected_chromedriver             0x000000010a41d6de undetected_chromedriver + 5060318
# 20  libsystem_pthread.dylib             0x00007fff203738fc _pthread_start + 224
# 21  libsystem_pthread.dylib             0x00007fff2036f443 thread_start + 15
#
# Comment 41: 1 - 【The whisper】COD ผ้าอ้อมผู้ใหญ่ 10PCS M/L/XL การดูดซับที่ดี รุ่นบางเบาระบายอากาศดี ใช้ได้ทั้งชายหญิง - 576 - s***. - นุ่มสบาย, นุ่มและอ่อนโยนต่อผิว, ความสามารถในการดูดซับที่ดี, แต่บางไปหน่อย ใส่กลางคืนแล้วรั่วซึมออกมา - Positive - 5
# Comment 42: 1 - 【The whisper】COD ผ้าอ้อมผู้ใหญ่ 10PCS M/L/XL การดูดซับที่ดี รุ่นบางเบาระบายอากาศดี ใช้ได้ทั้งชายหญิง - 576 - K***. - ผ้าหายใจได้, การป้องกันเอวสามมิติ, ความสามารถในการดูดซับที่ดี, ความสามารถในการดูดซับที่ดี, ความสามารถในการดูดซับที่ดี, - Positive - 5
# Comment 43: 1 - 【The whisper】COD ผ้าอ้อมผู้ใหญ่ 10PCS M/L/XL การดูดซับที่ดี รุ่นบางเบาระบายอากาศดี ใช้ได้ทั้งชายหญิง - 576 - ณิชารัศม์ น. - นุ่มและอ่อนโยนต่อผิว, ผ้าที่ระบายอากาศได้, แห้งเร็ว, การป้องกันเอวสามมิติ, คุณภาพยอดเยี่ยม, นุ่มและสบาย, - Positive - 5
# Comment 44: 1 - 【The whisper】COD ผ้าอ้อมผู้ใหญ่ 10PCS M/L/XL การดูดซับที่ดี รุ่นบางเบาระบายอากาศดี ใช้ได้ทั้งชายหญิง - 576 - สุภาวดี ผ. - สินค้าคุณภาพดี ราคาย่อม ไม่แพง ชอบๆ การร้านค้าดี การให้บริการขนส่งดี สบาย ไม่ต้องไปซื้อเอง ชอบมาก ชอบที่สุดเลย - Positive - 5
# Comment 45: 1 - 【The whisper】COD ผ้าอ้อมผู้ใหญ่ 10PCS M/L/XL การดูดซับที่ดี รุ่นบางเบาระบายอากาศดี ใช้ได้ทั้งชายหญิง - 576 - Yateng B. - นุ่มและอ่อนโยนต่อผิว, การแห้งเร็ว, การออกแบบในสไตล์กางเกงขาสั้นที่สะดวกสบาย, การป้องกันการรั่วซึม, นุ่มสบาย, ผ้าหายใจได้, ล็อคปลอดภัย, - Positive - 5
# An error occurred while handling the iframe: Message:
# Stacktrace:
# 0   undetected_chromedriver             0x000000010a4262a8 undetected_chromedriver + 5096104
# 1   undetected_chromedriver             0x000000010a41dada undetected_chromedriver + 5061338
# 2   undetected_chromedriver             0x0000000109fa8fd0 undetected_chromedriver + 389072
# 3   undetected_chromedriver             0x0000000109ff59ab undetected_chromedriver + 702891
# 4   undetected_chromedriver             0x0000000109ff5a81 undetected_chromedriver + 703105
# 5   undetected_chromedriver             0x000000010a039cd4 undetected_chromedriver + 982228
# 6   undetected_chromedriver             0x000000010a019f1d undetected_chromedriver + 851741
# 7   undetected_chromedriver             0x000000010a037250 undetected_chromedriver + 971344
# 8   undetected_chromedriver             0x000000010a019c93 undetected_chromedriver + 851091
# 9   undetected_chromedriver             0x0000000109fe8c79 undetected_chromedriver + 650361
# 10  undetected_chromedriver             0x0000000109fe949e undetected_chromedriver + 652446
# 11  undetected_chromedriver             0x000000010a3e9020 undetected_chromedriver + 4845600
# 12  undetected_chromedriver             0x000000010a3edf38 undetected_chromedriver + 4865848
# 13  undetected_chromedriver             0x000000010a3ee605 undetected_chromedriver + 4867589
# 14  undetected_chromedriver             0x000000010a3cbc59 undetected_chromedriver + 4725849
# 15  undetected_chromedriver             0x000000010a3ee8f9 undetected_chromedriver + 4868345
# 16  undetected_chromedriver             0x000000010a3bdb74 undetected_chromedriver + 4668276
# 17  undetected_chromedriver             0x000000010a40ddd8 undetected_chromedriver + 4996568
# 18  undetected_chromedriver             0x000000010a40dfd7 undetected_chromedriver + 4997079
# 19  undetected_chromedriver             0x000000010a41d6de undetected_chromedriver + 5060318
# 20  libsystem_pthread.dylib             0x00007fff203738fc _pthread_start + 224
# 21  libsystem_pthread.dylib             0x00007fff2036f443 thread_start + 15
#
# Comment 46: 1 - 【The whisper】COD ผ้าอ้อมผู้ใหญ่ 10PCS M/L/XL การดูดซับที่ดี รุ่นบางเบาระบายอากาศดี ใช้ได้ทั้งชายหญิง - 576 - Apple P. - การป้องกันการรั่วซึม, การออกแบบสไตล์กางเกงที่สะดวกสบาย, คุณภาพยอดเยี่ยม, การดูดซับที่ยอดเยี่ยม, ล็อคที่ปลอดภัย, แห้งเร็ว, นุ่มและสบาย, - Positive - 5
# Comment 47: 1 - 【The whisper】COD ผ้าอ้อมผู้ใหญ่ 10PCS M/L/XL การดูดซับที่ดี รุ่นบางเบาระบายอากาศดี ใช้ได้ทั้งชายหญิง - 576 - B***. - Excellent quality, Soft and gentle on the skin, Three-dimensional waist protection, Soft and gentle on the skin, - Positive - 5
# Comment 48: 1 - 【The whisper】COD ผ้าอ้อมผู้ใหญ่ 10PCS M/L/XL การดูดซับที่ดี รุ่นบางเบาระบายอากาศดี ใช้ได้ทั้งชายหญิง - 576 - sasanan J. - นุ่มสบาย, ผ้าหายใจได้, การออกแบบในสไตล์กางเกงขาสั้นที่สะดวกสบาย, การแห้งเร็ว, นุ่มและอ่อนโยนต่อผิว, - Positive - 5
# Comment 49: 1 - 【The whisper】COD ผ้าอ้อมผู้ใหญ่ 10PCS M/L/XL การดูดซับที่ดี รุ่นบางเบาระบายอากาศดี ใช้ได้ทั้งชายหญิง - 576 - Sirima K. - การออกแบบสไตล์กางเกงที่สะดวกสบาย, นุ่มและอ่อนโยนต่อผิว, ผ้าที่ระบายอากาศได้, การป้องกันเอวสามมิติ, แห้งเร็ว, - Positive - 5
# Comment 50: 1 - 【The whisper】COD ผ้าอ้อมผู้ใหญ่ 10PCS M/L/XL การดูดซับที่ดี รุ่นบางเบาระบายอากาศดี ใช้ได้ทั้งชายหญิง - 576 - เ***. - การแห้งเร็ว, คุณภาพเยี่ยม, การป้องกันเอวสามมิติ, นุ่มสบาย, การออกแบบในสไตล์กางเกงขาสั้นที่สะดวกสบาย, ล็อคปลอดภัย, ผ้าหายใจได้, - Positive - 5
# An error occurred while handling the iframe: Message:
# Stacktrace:
# 0   undetected_chromedriver             0x000000010a4262a8 undetected_chromedriver + 5096104
# 1   undetected_chromedriver             0x000000010a41dada undetected_chromedriver + 5061338
# 2   undetected_chromedriver             0x0000000109fa8fd0 undetected_chromedriver + 389072
# 3   undetected_chromedriver             0x0000000109ff59ab undetected_chromedriver + 702891
# 4   undetected_chromedriver             0x0000000109ff5a81 undetected_chromedriver + 703105
# 5   undetected_chromedriver             0x000000010a039cd4 undetected_chromedriver + 982228
# 6   undetected_chromedriver             0x000000010a019f1d undetected_chromedriver + 851741
# 7   undetected_chromedriver             0x000000010a037250 undetected_chromedriver + 971344
# 8   undetected_chromedriver             0x000000010a019c93 undetected_chromedriver + 851091
# 9   undetected_chromedriver             0x0000000109fe8c79 undetected_chromedriver + 650361
# 10  undetected_chromedriver             0x0000000109fe949e undetected_chromedriver + 652446
# 11  undetected_chromedriver             0x000000010a3e9020 undetected_chromedriver + 4845600
# 12  undetected_chromedriver             0x000000010a3edf38 undetected_chromedriver + 4865848
# 13  undetected_chromedriver             0x000000010a3ee605 undetected_chromedriver + 4867589
# 14  undetected_chromedriver             0x000000010a3cbc59 undetected_chromedriver + 4725849
# 15  undetected_chromedriver             0x000000010a3ee8f9 undetected_chromedriver + 4868345
# 16  undetected_chromedriver             0x000000010a3bdb74 undetected_chromedriver + 4668276
# 17  undetected_chromedriver             0x000000010a40ddd8 undetected_chromedriver + 4996568
# 18  undetected_chromedriver             0x000000010a40dfd7 undetected_chromedriver + 4997079
# 19  undetected_chromedriver             0x000000010a41d6de undetected_chromedriver + 5060318
# 20  libsystem_pthread.dylib             0x00007fff203738fc _pthread_start + 224
# 21  libsystem_pthread.dylib             0x00007fff2036f443 thread_start + 15
#
# Comment 51: 1 - 【The whisper】COD ผ้าอ้อมผู้ใหญ่ 10PCS M/L/XL การดูดซับที่ดี รุ่นบางเบาระบายอากาศดี ใช้ได้ทั้งชายหญิง - 576 - มะปราง ไ. - การออกแบบในสไตล์กางเกงขาสั้นที่สะดวกสบาย, นุ่มและอ่อนโยนต่อผิว, คุณภาพเยี่ยม, การป้องกันเอวสามมิติ, ความสามารถในการดูดซับที่ดี, - Positive - 5
# Comment 52: 1 - 【The whisper】COD ผ้าอ้อมผู้ใหญ่ 10PCS M/L/XL การดูดซับที่ดี รุ่นบางเบาระบายอากาศดี ใช้ได้ทั้งชายหญิง - 576 - S***. - การป้องกันเอวสามมิติ, การออกแบบในสไตล์กางเกงขาสั้นที่สะดวกสบาย, นุ่มสบาย, นุ่มและอ่อนโยนต่อผิว, การแห้งเร็ว, - Positive - 5
# Comment 53: 1 - 【The whisper】COD ผ้าอ้อมผู้ใหญ่ 10PCS M/L/XL การดูดซับที่ดี รุ่นบางเบาระบายอากาศดี ใช้ได้ทั้งชายหญิง - 576 - ผีญี่ปุ่น - ความสามารถในการดูดซับที่ดี, นุ่มสบาย, ล็อคปลอดภัย, ความสามารถในการดูดซับที่ดี, คุณภาพเยี่ยม, นุ่มและอ่อนโยนต่อผิว, การป้องกันเอวสามมิติ, ความสามารถในการดูดซับที่ดี, นุ่มและอ่อนโยนต่อผิว, นุ่มสบาย, ล็อคปลอดภัย, คุณภาพเยี่ยม, - Positive - 5
# Comment 54: 1 - 【The whisper】COD ผ้าอ้อมผู้ใหญ่ 10PCS M/L/XL การดูดซับที่ดี รุ่นบางเบาระบายอากาศดี ใช้ได้ทั้งชายหญิง - 576 - Kay 9. - ส่งสินค้าไวมาก ยังไม่ได้ลองว่าดีหรือเปล่า เอาไว้ใช้เวลาประจำเดือนมามากๆ สะดวกกว่าใช้ผ้าอนามัยเยอะเลย - Positive - 5
# Comment 55: 1 - 【The whisper】COD ผ้าอ้อมผู้ใหญ่ 10PCS M/L/XL การดูดซับที่ดี รุ่นบางเบาระบายอากาศดี ใช้ได้ทั้งชายหญิง - 576 - แพรวพรรณ ก. - ได้รับสินค้าเรียบร้อยค่ะ  ตามจำนวรที่สั่ง  แพ้คเกจมาดีค่ะ
# การออกแบบในสไตล์กางเกงขาสั้นที่สะดวกสบาย - Positive - 5
# An error occurred while handling the iframe: Message:
# Stacktrace:
# 0   undetected_chromedriver             0x000000010a4262a8 undetected_chromedriver + 5096104
# 1   undetected_chromedriver             0x000000010a41dada undetected_chromedriver + 5061338
# 2   undetected_chromedriver             0x0000000109fa8fd0 undetected_chromedriver + 389072
# 3   undetected_chromedriver             0x0000000109ff59ab undetected_chromedriver + 702891
# 4   undetected_chromedriver             0x0000000109ff5a81 undetected_chromedriver + 703105
# 5   undetected_chromedriver             0x000000010a039cd4 undetected_chromedriver + 982228
# 6   undetected_chromedriver             0x000000010a019f1d undetected_chromedriver + 851741
# 7   undetected_chromedriver             0x000000010a037250 undetected_chromedriver + 971344
# 8   undetected_chromedriver             0x000000010a019c93 undetected_chromedriver + 851091
# 9   undetected_chromedriver             0x0000000109fe8c79 undetected_chromedriver + 650361
# 10  undetected_chromedriver             0x0000000109fe949e undetected_chromedriver + 652446
# 11  undetected_chromedriver             0x000000010a3e9020 undetected_chromedriver + 4845600
# 12  undetected_chromedriver             0x000000010a3edf38 undetected_chromedriver + 4865848
# 13  undetected_chromedriver             0x000000010a3ee605 undetected_chromedriver + 4867589
# 14  undetected_chromedriver             0x000000010a3cbc59 undetected_chromedriver + 4725849
# 15  undetected_chromedriver             0x000000010a3ee8f9 undetected_chromedriver + 4868345
# 16  undetected_chromedriver             0x000000010a3bdb74 undetected_chromedriver + 4668276
# 17  undetected_chromedriver             0x000000010a40ddd8 undetected_chromedriver + 4996568
# 18  undetected_chromedriver             0x000000010a40dfd7 undetected_chromedriver + 4997079
# 19  undetected_chromedriver             0x000000010a41d6de undetected_chromedriver + 5060318
# 20  libsystem_pthread.dylib             0x00007fff203738fc _pthread_start + 224
# 21  libsystem_pthread.dylib             0x00007fff2036f443 thread_start + 15
#
# Comment 56: 1 - 【The whisper】COD ผ้าอ้อมผู้ใหญ่ 10PCS M/L/XL การดูดซับที่ดี รุ่นบางเบาระบายอากาศดี ใช้ได้ทั้งชายหญิง - 576 - B***. - Breathable fabric, Soft and comfortable, Soft and gentle on the skin, Great absorbency, Quick drying, - Positive - 5
# Comment 57: 1 - 【The whisper】COD ผ้าอ้อมผู้ใหญ่ 10PCS M/L/XL การดูดซับที่ดี รุ่นบางเบาระบายอากาศดี ใช้ได้ทั้งชายหญิง - 576 - ศศวิน ป. - เคยลองใช้แม่บอกพอใช้ได้ ราคาไม่แพง ส่งไว คราวนี้ดีไม่เสียค่าส่งไม่ต้องซื้อของเพิ่ม ถ้าเสียค่าส่งก็ไปเลือกยี่ห้ออื่น - Positive - 5
# Comment 58: 1 - 【The whisper】COD ผ้าอ้อมผู้ใหญ่ 10PCS M/L/XL การดูดซับที่ดี รุ่นบางเบาระบายอากาศดี ใช้ได้ทั้งชายหญิง - 576 - Nine - คุณภาพยอดเยี่ยม, การออกแบบสไตล์กางเกงที่สะดวกสบาย, การออกแบบสไตล์กางเกงที่สะดวกสบาย, การป้องกันการรั่วซึม, แห้งเร็ว, ผ้าที่ระบายอากาศได้, - Positive - 5
# Comment 59: 1 - 【The whisper】COD ผ้าอ้อมผู้ใหญ่ 10PCS M/L/XL การดูดซับที่ดี รุ่นบางเบาระบายอากาศดี ใช้ได้ทั้งชายหญิง - 576 - 0***7 - นุ่มสบาย, การออกแบบในสไตล์กางเกงขาสั้นที่สะดวกสบาย, ล็อคปลอดภัย, นุ่มและอ่อนโยนต่อผิว, คุณภาพเยี่ยม, การป้องกันการรั่วซึม, - Positive - 5
# Comment 60: 1 - 【The whisper】COD ผ้าอ้อมผู้ใหญ่ 10PCS M/L/XL การดูดซับที่ดี รุ่นบางเบาระบายอากาศดี ใช้ได้ทั้งชายหญิง - 576 - P***e - ผ้าหายใจได้, การแห้งเร็ว, การป้องกันเอวสามมิติ, คุณภาพเยี่ยม, การป้องกันการรั่วซึม, ล็อคปลอดภัย, - Positive - 5
# An error occurred while handling the iframe: Message:
# Stacktrace:
# 0   undetected_chromedriver             0x000000010a4262a8 undetected_chromedriver + 5096104
# 1   undetected_chromedriver             0x000000010a41dada undetected_chromedriver + 5061338
# 2   undetected_chromedriver             0x0000000109fa8fd0 undetected_chromedriver + 389072
# 3   undetected_chromedriver             0x0000000109ff59ab undetected_chromedriver + 702891
# 4   undetected_chromedriver             0x0000000109ff5a81 undetected_chromedriver + 703105
# 5   undetected_chromedriver             0x000000010a039cd4 undetected_chromedriver + 982228
# 6   undetected_chromedriver             0x000000010a019f1d undetected_chromedriver + 851741
# 7   undetected_chromedriver             0x000000010a037250 undetected_chromedriver + 971344
# 8   undetected_chromedriver             0x000000010a019c93 undetected_chromedriver + 851091
# 9   undetected_chromedriver             0x0000000109fe8c79 undetected_chromedriver + 650361
# 10  undetected_chromedriver             0x0000000109fe949e undetected_chromedriver + 652446
# 11  undetected_chromedriver             0x000000010a3e9020 undetected_chromedriver + 4845600
# 12  undetected_chromedriver             0x000000010a3edf38 undetected_chromedriver + 4865848
# 13  undetected_chromedriver             0x000000010a3ee605 undetected_chromedriver + 4867589
# 14  undetected_chromedriver             0x000000010a3cbc59 undetected_chromedriver + 4725849
# 15  undetected_chromedriver             0x000000010a3ee8f9 undetected_chromedriver + 4868345
# 16  undetected_chromedriver             0x000000010a3bdb74 undetected_chromedriver + 4668276
# 17  undetected_chromedriver             0x000000010a40ddd8 undetected_chromedriver + 4996568
# 18  undetected_chromedriver             0x000000010a40dfd7 undetected_chromedriver + 4997079
# 19  undetected_chromedriver             0x000000010a41d6de undetected_chromedriver + 5060318
# 20  libsystem_pthread.dylib             0x00007fff203738fc _pthread_start + 224
# 21  libsystem_pthread.dylib             0x00007fff2036f443 thread_start + 15
#
# Comment 61: 1 - 【The whisper】COD ผ้าอ้อมผู้ใหญ่ 10PCS M/L/XL การดูดซับที่ดี รุ่นบางเบาระบายอากาศดี ใช้ได้ทั้งชายหญิง - 576 - ป***. - การป้องกันการรั่วซึม, ผ้าหายใจได้, ล็อคปลอดภัย, การแห้งเร็ว, นุ่มสบาย, ผ้าหายใจได้, ล็อคปลอดภัย, - Positive - 5
# Comment 62: 1 - 【The whisper】COD ผ้าอ้อมผู้ใหญ่ 10PCS M/L/XL การดูดซับที่ดี รุ่นบางเบาระบายอากาศดี ใช้ได้ทั้งชายหญิง - 576 - นิสารัตน์ แ. - ความสามารถในการดูดซับที่ดี, แห้งเร็ว, ผ้าหายใจได้, การป้องกันการรั่วซึม, นุ่มสบาย, คุณภาพเยี่ยม, - Positive - 5
# Comment 63: 1 - 【The whisper】COD ผ้าอ้อมผู้ใหญ่ 10PCS M/L/XL การดูดซับที่ดี รุ่นบางเบาระบายอากาศดี ใช้ได้ทั้งชายหญิง - 576 - 0***2 - นุ่มสบาย, การป้องกันการรั่วซึม, ความสามารถในการดูดซับที่ดี, นุ่มและอ่อนโยนต่อผิว, คุณภาพเยี่ยม, - Positive - 5
# Comment 64: 1 - 【The whisper】COD ผ้าอ้อมผู้ใหญ่ 10PCS M/L/XL การดูดซับที่ดี รุ่นบางเบาระบายอากาศดี ใช้ได้ทั้งชายหญิง - 576 - K***h - คุณภาพเยี่ยม, นุ่มสบาย, การป้องกันการรั่วซึม, ความสามารถในการดูดซับที่ดี, การป้องกันเอวสามมิติ, - Positive - 5
# Comment 65: 1 - 【The whisper】COD ผ้าอ้อมผู้ใหญ่ 10PCS M/L/XL การดูดซับที่ดี รุ่นบางเบาระบายอากาศดี ใช้ได้ทั้งชายหญิง - 576 - Kesharat H. - ตรงตามสั่ง หีบห่อมาดี ส่งเร็ว คุณภาพเหมาะสมกับราคา ไม่หนา สามารถป้องกันการรั่วซึมได้ในระดับหนึ่ง - Positive - 5
# An error occurred while handling the iframe: Message:
# Stacktrace:
# 0   undetected_chromedriver             0x000000010a4262a8 undetected_chromedriver + 5096104
# 1   undetected_chromedriver             0x000000010a41dada undetected_chromedriver + 5061338
# 2   undetected_chromedriver             0x0000000109fa8fd0 undetected_chromedriver + 389072
# 3   undetected_chromedriver             0x0000000109ff59ab undetected_chromedriver + 702891
# 4   undetected_chromedriver             0x0000000109ff5a81 undetected_chromedriver + 703105
# 5   undetected_chromedriver             0x000000010a039cd4 undetected_chromedriver + 982228
# 6   undetected_chromedriver             0x000000010a019f1d undetected_chromedriver + 851741
# 7   undetected_chromedriver             0x000000010a037250 undetected_chromedriver + 971344
# 8   undetected_chromedriver             0x000000010a019c93 undetected_chromedriver + 851091
# 9   undetected_chromedriver             0x0000000109fe8c79 undetected_chromedriver + 650361
# 10  undetected_chromedriver             0x0000000109fe949e undetected_chromedriver + 652446
# 11  undetected_chromedriver             0x000000010a3e9020 undetected_chromedriver + 4845600
# 12  undetected_chromedriver             0x000000010a3edf38 undetected_chromedriver + 4865848
# 13  undetected_chromedriver             0x000000010a3ee605 undetected_chromedriver + 4867589
# 14  undetected_chromedriver             0x000000010a3cbc59 undetected_chromedriver + 4725849
# 15  undetected_chromedriver             0x000000010a3ee8f9 undetected_chromedriver + 4868345
# 16  undetected_chromedriver             0x000000010a3bdb74 undetected_chromedriver + 4668276
# 17  undetected_chromedriver             0x000000010a40ddd8 undetected_chromedriver + 4996568
# 18  undetected_chromedriver             0x000000010a40dfd7 undetected_chromedriver + 4997079
# 19  undetected_chromedriver             0x000000010a41d6de undetected_chromedriver + 5060318
# 20  libsystem_pthread.dylib             0x00007fff203738fc _pthread_start + 224
# 21  libsystem_pthread.dylib             0x00007fff2036f443 thread_start + 15
#
# Comment 66: 1 - 【The whisper】COD ผ้าอ้อมผู้ใหญ่ 10PCS M/L/XL การดูดซับที่ดี รุ่นบางเบาระบายอากาศดี ใช้ได้ทั้งชายหญิง - 576 - B***. - Three-dimensional waist protection, Great absorbency, Leak-proof protection, Great absorbency, - Positive - 5
# Comment 67: 1 - 【The whisper】COD ผ้าอ้อมผู้ใหญ่ 10PCS M/L/XL การดูดซับที่ดี รุ่นบางเบาระบายอากาศดี ใช้ได้ทั้งชายหญิง - 576 - การต์รวี จ. - สั่งเมืองานได้วันนี้ของถึงแร็วรอไม่นานคะคุณภาพเดียวรองให้พ่อใส่ดูก่อนนะคะดีจะกลับมาสั่งให้ม่คะ - Positive - 5
# Comment 68: 1 - 【The whisper】COD ผ้าอ้อมผู้ใหญ่ 10PCS M/L/XL การดูดซับที่ดี รุ่นบางเบาระบายอากาศดี ใช้ได้ทั้งชายหญิง - 576 - ร***. - การดูดซับที่ยอดเยี่ยม, การป้องกันเอวสามมิติ, คุณภาพยอดเยี่ยม, แห้งเร็ว, นุ่มและอ่อนโยนต่อผิว, - Positive - 5
# Comment 69: 1 - 【The whisper】COD ผ้าอ้อมผู้ใหญ่ 10PCS M/L/XL การดูดซับที่ดี รุ่นบางเบาระบายอากาศดี ใช้ได้ทั้งชายหญิง - 576 - คณารัตน์ ม. - การแห้งเร็ว, นุ่มสบาย, นุ่มและอ่อนโยนต่อผิว, ล็อคปลอดภัย, การป้องกันเอวสามมิติ, ผ้าหายใจได้, - Positive - 5
# ...
# 3   undetected_chromedriver             0x0000000109ff59ab undetected_chromedriver + 702891
# 4   undetected_chromedriver             0x0000000109ff5a81 undetected_chromedriver + 703105
# 5   undetected_chromedriver             0x000000010a039cd4 undetected_chromedriver + 982228
# 6   undetected_chromedriver             0x000000010a019f1d undetected_chromedriver + 851741
# 7   undetected_chromedriver             0x000000010a037250 undetected_chromedriver + 971344
# 8   undetected_chromedriver             0x000000010a019c93 undetected_chromedriver + 851091
# 9   undetected_chromedriver             0x0000000109fe8c79 undetected_chromedriver + 650361
# 10  undetected_chromedriver             0x0000000109fe949e undetected_chromedriver + 652446
# 11  undetected_chromedriver             0x000000010a3e9020 undetected_chromedriver + 4845600
# 12  undetected_chromedriver             0x000000010a3edf38 undetected_chromedriver + 4865848
# 13  undetected_chromedriver             0x000000010a3ee605 undetected_chromedriver + 4867589
# 14  undetected_chromedriver             0x000000010a3cbc59 undetected_chromedriver + 4725849
# 15  undetected_chromedriver             0x000000010a3ee8f9 undetected_chromedriver + 4868345
# 16  undetected_chromedriver             0x000000010a3bdb74 undetected_chromedriver + 4668276
# 17  undetected_chromedriver             0x000000010a40ddd8 undetected_chromedriver + 4996568
# 18  undetected_chromedriver             0x000000010a40dfd7 undetected_chromedriver + 4997079
# 19  undetected_chromedriver             0x000000010a41d6de undetected_chromedriver + 5060318
# 20  libsystem_pthread.dylib             0x00007fff203738fc _pthread_start + 224
# 21  libsystem_pthread.dylib             0x00007fff2036f443 thread_start + 15
#
# Comment 546: 1 - 【The whisper】COD ผ้าอ้อมผู้ใหญ่ 10PCS M/L/XL การดูดซับที่ดี รุ่นบางเบาระบายอากาศดี ใช้ได้ทั้งชายหญิง - 576 - ทัศนีย์ ก. - ยไม่ระคาย แผ่นซึมซับมีขนาดใหญ่ นุ่มและอ่อนโยนต่อผิว,
# พอใจมากราคาถูก - Positive - 4
# Comment 547: 1 - 【The whisper】COD ผ้าอ้อมผู้ใหญ่ 10PCS M/L/XL การดูดซับที่ดี รุ่นบางเบาระบายอากาศดี ใช้ได้ทั้งชายหญิง - 576 - พ***. - การป้องกันเอวสามมิติ, นุ่มและสบาย, แห้งเร็ว, ล็อคที่ปลอดภัย, นุ่มและอ่อนโยนต่อผิว, ผ้าที่ระบายอากาศได้, - Positive - 4
# Comment 548: 1 - 【The whisper】COD ผ้าอ้อมผู้ใหญ่ 10PCS M/L/XL การดูดซับที่ดี รุ่นบางเบาระบายอากาศดี ใช้ได้ทั้งชายหญิง - 576 - เจน - นุ่มสบาย, การออกแบบในสไตล์กางเกงขาสั้นที่สะดวกสบาย, น่าจะนุ่มและอ่อนโยนต่อผิว, - Positive - 4
# Comment 549: 1 - 【The whisper】COD ผ้าอ้อมผู้ใหญ่ 10PCS M/L/XL การดูดซับที่ดี รุ่นบางเบาระบายอากาศดี ใช้ได้ทั้งชายหญิง - 576 - *******982 - Soft and comfortable,Breathable fabric, - Positive - 4
# Comment 550: 1 - 【The whisper】COD ผ้าอ้อมผู้ใหญ่ 10PCS M/L/XL การดูดซับที่ดี รุ่นบางเบาระบายอากาศดี ใช้ได้ทั้งชายหญิง - 576 - *******492 -  - Positive - 4
# An error occurred while handling the iframe: Message:
# Stacktrace:
# 0   undetected_chromedriver             0x000000010a4262a8 undetected_chromedriver + 5096104
# 1   undetected_chromedriver             0x000000010a41dada undetected_chromedriver + 5061338
# 2   undetected_chromedriver             0x0000000109fa8fd0 undetected_chromedriver + 389072
# 3   undetected_chromedriver             0x0000000109ff59ab undetected_chromedriver + 702891
# 4   undetected_chromedriver             0x0000000109ff5a81 undetected_chromedriver + 703105
# 5   undetected_chromedriver             0x000000010a039cd4 undetected_chromedriver + 982228
# 6   undetected_chromedriver             0x000000010a019f1d undetected_chromedriver + 851741
# 7   undetected_chromedriver             0x000000010a037250 undetected_chromedriver + 971344
# 8   undetected_chromedriver             0x000000010a019c93 undetected_chromedriver + 851091
# 9   undetected_chromedriver             0x0000000109fe8c79 undetected_chromedriver + 650361
# 10  undetected_chromedriver             0x0000000109fe949e undetected_chromedriver + 652446
# 11  undetected_chromedriver             0x000000010a3e9020 undetected_chromedriver + 4845600
# 12  undetected_chromedriver             0x000000010a3edf38 undetected_chromedriver + 4865848
# 13  undetected_chromedriver             0x000000010a3ee605 undetected_chromedriver + 4867589
# 14  undetected_chromedriver             0x000000010a3cbc59 undetected_chromedriver + 4725849
# 15  undetected_chromedriver             0x000000010a3ee8f9 undetected_chromedriver + 4868345
# 16  undetected_chromedriver             0x000000010a3bdb74 undetected_chromedriver + 4668276
# 17  undetected_chromedriver             0x000000010a40ddd8 undetected_chromedriver + 4996568
# 18  undetected_chromedriver             0x000000010a40dfd7 undetected_chromedriver + 4997079
# 19  undetected_chromedriver             0x000000010a41d6de undetected_chromedriver + 5060318
# 20  libsystem_pthread.dylib             0x00007fff203738fc _pthread_start + 224
# 21  libsystem_pthread.dylib             0x00007fff2036f443 thread_start + 15
#
# Comment 551: 1 - 【The whisper】COD ผ้าอ้อมผู้ใหญ่ 10PCS M/L/XL การดูดซับที่ดี รุ่นบางเบาระบายอากาศดี ใช้ได้ทั้งชายหญิง - 576 - บุญญฤทธิ์ บ. -  - Positive - 4
# Comment 552: 1 - 【The whisper】COD ผ้าอ้อมผู้ใหญ่ 10PCS M/L/XL การดูดซับที่ดี รุ่นบางเบาระบายอากาศดี ใช้ได้ทั้งชายหญิง - 576 - Thanyanan M. -  - Positive - 4
# Comment 553: 1 - 【The whisper】COD ผ้าอ้อมผู้ใหญ่ 10PCS M/L/XL การดูดซับที่ดี รุ่นบางเบาระบายอากาศดี ใช้ได้ทั้งชายหญิง - 576 - kanokarn C. -  - Positive - 4
# Comment 554: 1 - 【The whisper】COD ผ้าอ้อมผู้ใหญ่ 10PCS M/L/XL การดูดซับที่ดี รุ่นบางเบาระบายอากาศดี ใช้ได้ทั้งชายหญิง - 576 - 0***5 -  - Positive - 4
# An error occurred while handling the iframe: Message:
# Stacktrace:
# 0   undetected_chromedriver             0x000000010a4262a8 undetected_chromedriver + 5096104
# 1   undetected_chromedriver             0x000000010a41dada undetected_chromedriver + 5061338
# 2   undetected_chromedriver             0x0000000109fa8fd0 undetected_chromedriver + 389072
# 3   undetected_chromedriver             0x0000000109ff59ab undetected_chromedriver + 702891
# 4   undetected_chromedriver             0x0000000109ff5a81 undetected_chromedriver + 703105
# 5   undetected_chromedriver             0x000000010a039cd4 undetected_chromedriver + 982228
# 6   undetected_chromedriver             0x000000010a019f1d undetected_chromedriver + 851741
# 7   undetected_chromedriver             0x000000010a037250 undetected_chromedriver + 971344
# 8   undetected_chromedriver             0x000000010a019c93 undetected_chromedriver + 851091
# 9   undetected_chromedriver             0x0000000109fe8c79 undetected_chromedriver + 650361
# 10  undetected_chromedriver             0x0000000109fe949e undetected_chromedriver + 652446
# 11  undetected_chromedriver             0x000000010a3e9020 undetected_chromedriver + 4845600
# 12  undetected_chromedriver             0x000000010a3edf38 undetected_chromedriver + 4865848
# 13  undetected_chromedriver             0x000000010a3ee605 undetected_chromedriver + 4867589
# 14  undetected_chromedriver             0x000000010a3cbc59 undetected_chromedriver + 4725849
# 15  undetected_chromedriver             0x000000010a3ee8f9 undetected_chromedriver + 4868345
# 16  undetected_chromedriver             0x000000010a3bdb74 undetected_chromedriver + 4668276
# 17  undetected_chromedriver             0x000000010a40ddd8 undetected_chromedriver + 4996568
# 18  undetected_chromedriver             0x000000010a40dfd7 undetected_chromedriver + 4997079
# 19  undetected_chromedriver             0x000000010a41d6de undetected_chromedriver + 5060318
# 20  libsystem_pthread.dylib             0x00007fff203738fc _pthread_start + 224
# 21  libsystem_pthread.dylib             0x00007fff2036f443 thread_start + 15
#
# Comment 555: 1 - 【The whisper】COD ผ้าอ้อมผู้ใหญ่ 10PCS M/L/XL การดูดซับที่ดี รุ่นบางเบาระบายอากาศดี ใช้ได้ทั้งชายหญิง - 576 - kolf5347 - เอ็มใหญ่เวอร์....,.,................................................!............ - Neutral - 3
# Comment 556: 1 - 【The whisper】COD ผ้าอ้อมผู้ใหญ่ 10PCS M/L/XL การดูดซับที่ดี รุ่นบางเบาระบายอากาศดี ใช้ได้ทั้งชายหญิง - 576 - สุภานัน เ. - สั่งไซส์L 4 ห่อ ได้M มา 2ห่อ  L 2 ห่อ แถมบาง และยางตามขอบมุมกางเกงย้วยเกิน ไม่กระชับ - Neutral - 3
# Comment 557: 1 - 【The whisper】COD ผ้าอ้อมผู้ใหญ่ 10PCS M/L/XL การดูดซับที่ดี รุ่นบางเบาระบายอากาศดี ใช้ได้ทั้งชายหญิง - 576 - ปลาLine - บางไปคะ - Neutral - 3
# Comment 558: 1 - 【The whisper】COD ผ้าอ้อมผู้ใหญ่ 10PCS M/L/XL การดูดซับที่ดี รุ่นบางเบาระบายอากาศดี ใช้ได้ทั้งชายหญิง - 576 - Rung R. -  - Neutral - 3
# Comment 559: 1 - 【The whisper】COD ผ้าอ้อมผู้ใหญ่ 10PCS M/L/XL การดูดซับที่ดี รุ่นบางเบาระบายอากาศดี ใช้ได้ทั้งชายหญิง - 576 - Alexs'Sander -  - Neutral - 3
# An error occurred while handling the iframe: Message:
# Stacktrace:
# 0   undetected_chromedriver             0x000000010a4262a8 undetected_chromedriver + 5096104
# 1   undetected_chromedriver             0x000000010a41dada undetected_chromedriver + 5061338
# 2   undetected_chromedriver             0x0000000109fa8fd0 undetected_chromedriver + 389072
# 3   undetected_chromedriver             0x0000000109ff59ab undetected_chromedriver + 702891
# 4   undetected_chromedriver             0x0000000109ff5a81 undetected_chromedriver + 703105
# 5   undetected_chromedriver             0x000000010a039cd4 undetected_chromedriver + 982228
# 6   undetected_chromedriver             0x000000010a019f1d undetected_chromedriver + 851741
# 7   undetected_chromedriver             0x000000010a037250 undetected_chromedriver + 971344
# 8   undetected_chromedriver             0x000000010a019c93 undetected_chromedriver + 851091
# 9   undetected_chromedriver             0x0000000109fe8c79 undetected_chromedriver + 650361
# 10  undetected_chromedriver             0x0000000109fe949e undetected_chromedriver + 652446
# 11  undetected_chromedriver             0x000000010a3e9020 undetected_chromedriver + 4845600
# 12  undetected_chromedriver             0x000000010a3edf38 undetected_chromedriver + 4865848
# 13  undetected_chromedriver             0x000000010a3ee605 undetected_chromedriver + 4867589
# 14  undetected_chromedriver             0x000000010a3cbc59 undetected_chromedriver + 4725849
# 15  undetected_chromedriver             0x000000010a3ee8f9 undetected_chromedriver + 4868345
# 16  undetected_chromedriver             0x000000010a3bdb74 undetected_chromedriver + 4668276
# 17  undetected_chromedriver             0x000000010a40ddd8 undetected_chromedriver + 4996568
# 18  undetected_chromedriver             0x000000010a40dfd7 undetected_chromedriver + 4997079
# 19  undetected_chromedriver             0x000000010a41d6de undetected_chromedriver + 5060318
# 20  libsystem_pthread.dylib             0x00007fff203738fc _pthread_start + 224
# 21  libsystem_pthread.dylib             0x00007fff2036f443 thread_start + 15
#
# Comment 560: 1 - 【The whisper】COD ผ้าอ้อมผู้ใหญ่ 10PCS M/L/XL การดูดซับที่ดี รุ่นบางเบาระบายอากาศดี ใช้ได้ทั้งชายหญิง - 576 - ขนิษฐา -  - Neutral - 3
# Comment 561: 1 - 【The whisper】COD ผ้าอ้อมผู้ใหญ่ 10PCS M/L/XL การดูดซับที่ดี รุ่นบางเบาระบายอากาศดี ใช้ได้ทั้งชายหญิง - 576 - Mit29 K. -  - Neutral - 3
# An error occurred while handling the iframe: Message:
# Stacktrace:
# 0   undetected_chromedriver             0x000000010a4262a8 undetected_chromedriver + 5096104
# 1   undetected_chromedriver             0x000000010a41dada undetected_chromedriver + 5061338
# 2   undetected_chromedriver             0x0000000109fa8fd0 undetected_chromedriver + 389072
# 3   undetected_chromedriver             0x0000000109ff59ab undetected_chromedriver + 702891
# 4   undetected_chromedriver             0x0000000109ff5a81 undetected_chromedriver + 703105
# 5   undetected_chromedriver             0x000000010a039cd4 undetected_chromedriver + 982228
# 6   undetected_chromedriver             0x000000010a019f1d undetected_chromedriver + 851741
# 7   undetected_chromedriver             0x000000010a037250 undetected_chromedriver + 971344
# 8   undetected_chromedriver             0x000000010a019c93 undetected_chromedriver + 851091
# 9   undetected_chromedriver             0x0000000109fe8c79 undetected_chromedriver + 650361
# 10  undetected_chromedriver             0x0000000109fe949e undetected_chromedriver + 652446
# 11  undetected_chromedriver             0x000000010a3e9020 undetected_chromedriver + 4845600
# 12  undetected_chromedriver             0x000000010a3edf38 undetected_chromedriver + 4865848
# 13  undetected_chromedriver             0x000000010a3ee605 undetected_chromedriver + 4867589
# 14  undetected_chromedriver             0x000000010a3cbc59 undetected_chromedriver + 4725849
# 15  undetected_chromedriver             0x000000010a3ee8f9 undetected_chromedriver + 4868345
# 16  undetected_chromedriver             0x000000010a3bdb74 undetected_chromedriver + 4668276
# 17  undetected_chromedriver             0x000000010a40ddd8 undetected_chromedriver + 4996568
# 18  undetected_chromedriver             0x000000010a40dfd7 undetected_chromedriver + 4997079
# 19  undetected_chromedriver             0x000000010a41d6de undetected_chromedriver + 5060318
# 20  libsystem_pthread.dylib             0x00007fff203738fc _pthread_start + 224
# 21  libsystem_pthread.dylib             0x00007fff2036f443 thread_start + 15
#
# Comment 562: 1 - 【The whisper】COD ผ้าอ้อมผู้ใหญ่ 10PCS M/L/XL การดูดซับที่ดี รุ่นบางเบาระบายอากาศดี ใช้ได้ทั้งชายหญิง - 576 - siriratchani - คุณภาพเยี่ยมเนื้อวัสุดนิ่ม, นุ่มสบาย, สวมใส่ง่ายสำหรับผู้ป่วยที่ไม่ติดเตียง ล็อคปลอดภัย, - Negative - 1
# Comment 563: 1 - 【The whisper】COD ผ้าอ้อมผู้ใหญ่ 10PCS M/L/XL การดูดซับที่ดี รุ่นบางเบาระบายอากาศดี ใช้ได้ทั้งชายหญิง - 576 - จ***. - ไช้งานไม่ดีเลยขากางเกงไม่รู้จะใหญ่ไปไหนเห็นมียางยืดเท่าเส้นด้ายเลยได้ขัดฟันใหญ่กว่าจริงๆยางยืดขอบกางเกงประมาณเท่าเส้นผมคนเรานี้ละ บางที่อาจจะใหญ่กว่านะ สมควรกับราคาเหรอแบบนี้ ก้อครั้งเดีนว ใช้ไปตัวเดียวสั่งตัวเดิมที่เคยใช้เลย ที่สั่งมาจะไปทำอะไรว่ากันอีกที่ เอาไปบริจาก หรอเอาไปฉีกแล้วปุเปนที่นอนไห้ลูกแมวก้อดีนะ ของถุกมีคุณภาพก้อมีนะแต้นี้ทำมาได้ไงยางยืดขอบกางเกงเท่าเส้นผมคิดได้ไง - Negative - 1
#       id  Id_Item                                               Item Quantity  \
# 0      1        1  【The whisper】COD ผ้าอ้อมผู้ใหญ่ 10PCS M/L/XL ก...      576
# 1      2        1  【The whisper】COD ผ้าอ้อมผู้ใหญ่ 10PCS M/L/XL ก...      576
# 2      3        1  【The whisper】COD ผ้าอ้อมผู้ใหญ่ 10PCS M/L/XL ก...      576
# 3      4        1  【The whisper】COD ผ้าอ้อมผู้ใหญ่ 10PCS M/L/XL ก...      576
# 4      5        1  【The whisper】COD ผ้าอ้อมผู้ใหญ่ 10PCS M/L/XL ก...      576
# ..   ...      ...                                                ...      ...
# 558  559        1  【The whisper】COD ผ้าอ้อมผู้ใหญ่ 10PCS M/L/XL ก...      576
# 559  560        1  【The whisper】COD ผ้าอ้อมผู้ใหญ่ 10PCS M/L/XL ก...      576
# 560  561        1  【The whisper】COD ผ้าอ้อมผู้ใหญ่ 10PCS M/L/XL ก...      576
# 561  562        1  【The whisper】COD ผ้าอ้อมผู้ใหญ่ 10PCS M/L/XL ก...      576
# 562  563        1  【The whisper】COD ผ้าอ้อมผู้ใหญ่ 10PCS M/L/XL ก...      576
#
#              User                                            Message  \
# 0      *******333  การป้องกันเอวสามมิติ, คุณภาพเยี่ยม, ผ้าหายใจได...
# 1          นาง ส.  ขนาดกำลังดีนะเดี๋ยวจะลองใช้ดู รคาดีมากขนส่งเร็...
# 2          จิดาภา  การแห้งเร็ว, ผ้าหายใจได้, นุ่มและอ่อนโยนต่อผิว...
# 3     คณารัตน์ ม.  ล็อคปลอดภัย, ความสามารถในการดูดซับที่ดี, คุณภา...
# 4           B***.  Quick drying, Leak-proof protection, Soft and ...
# ..            ...                                                ...
# 558  Alexs'Sander
# 559        ขนิษฐา
# 560      Mit29 K.
# 561  siriratchani  คุณภาพเยี่ยมเนื้อวัสุดนิ่ม, นุ่มสบาย, สวมใส่ง่...
# 562         จ***.  ไช้งานไม่ดีเลยขากางเกงไม่รู้จะใหญ่ไปไหนเห็นมีย...
#
#     Sentiment  Star_rating
# 0    Positive            5
# 1    Positive            5
# 2    Positive            5
# 3    Positive            5
# 4    Positive            5
# ..        ...          ...
# 558   Neutral            3
# 559   Neutral            3
# 560   Neutral            3
# 561  Negative            1
# 562  Negative            1
#
# [563 rows x 8 columns]

# %%
# Check if there are comments to be saved to Excel
if not df.empty:
    # Get the path to the Downloads folder
    downloads_path = os.path.join(os.path.expanduser("~"), "Downloads")
    # Save DataFrame to Excel file in the Downloads folder
    excel_file_path = os.path.join(downloads_path, "comments.xlsx")
    df.to_excel(excel_file_path, index=False, na_rep='-')
    print("Comments saved to Excel.")
# Out:
# Comments saved to Excel.
